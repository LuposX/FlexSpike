# %% [markdown]
# ## 1. About
#
# This notebook is used to generate graphcis for my bachelor thesis.
#
# ## 2. Code
#
# ### 2.1 Illustration SNN

# %%
import snntorch as snn
from snntorch import surrogate
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.rcParams.update({
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 300,
    "savefig.dpi": 300,
    "font.family": "serif"
})

# %%
# Define simulation parameters
beta = 0.9  # membrane potential decay rate
threshold = 1  # neuron firing threshold
spike_grad = surrogate.atan()  # surrogate gradient for backpropagation
num_steps = 200  # simulation duration in time steps
input_size = 1 # Define input size explicitly

# Initialize LIF neuron
# Note: We remove init_hidden=True because we will manually manage the state
lif1 = snn.Leaky(beta=beta, threshold=threshold, spike_grad=spike_grad)

# Generate input spikes (similar to your image)
input_spikes = torch.zeros(num_steps, input_size)
input_spikes[10] = 1.0
input_spikes[80:100:5] = 1.0
input_spikes[120:128:2] = 1.0
input_spikes[140:148:4] = 1.0
input_spikes[160:168:4] = 1.0
input_spikes[180:188:4] = 1.0
input_spikes[195] = 1.0

# Store membrane potential and output spikes
mem_rec = []
spk_rec = []

# --- FIX: Initialize the internal states for the first step ---
mem = lif1.init_leaky() # Use the utility to initialize the membrane potential
spk = torch.zeros(input_size) # Initialize spike history (optional, but good practice)

# Simulate the neuron
for step in range(num_steps):
    # --- FIX: Pass the previous membrane potential (mem) as the second argument ---
    spk_out, mem_out = lif1(input_spikes[step].unsqueeze(0), mem)
    
    # Update the internal state for the next step
    mem = mem_out
    
    mem_rec.append(mem_out)
    spk_rec.append(spk_out)

# Convert lists to tensors
mem_rec = torch.stack(mem_rec).squeeze() # Squeeze to remove extra dimensions
spk_rec = torch.stack(spk_rec).squeeze()

# Plotting (Rest of your plotting code remains the same)
fig, ax = plt.subplots(3, figsize=(8, 6), sharex=True)

# Input Spikes
ax[0].plot(input_spikes.squeeze().numpy(), color='black')
ax[0].set_title("Input Spikes")
ax[0].set_ylabel("Input Spikes")
ax[0].set_yticks([0, 1])
ax[0].set_yticklabels(['', '1'])
ax[0].set_xticks([])
ax[0].set_xlim([0, num_steps])
ax[0].set_ylim([-0.1, 1.1])

# Membrane Potential
ax[1].plot(mem_rec.numpy())
ax[1].axhline(y=threshold, linestyle='--', color='gray', label='Threshold')
ax[1].set_title("Potential U(t)")
ax[1].set_ylabel("Potential U(t)")
# Adjusted y-limits for better visibility
ax[1].set_ylim([-0.1, 1.5]) 
ax[1].text(num_steps - 20, threshold + 0.05, r'$\vartheta$', fontsize=16)

# Output Spikes
ax[2].plot(spk_rec.numpy(), color='black')
ax[2].set_title("Output Spikes")
ax[2].set_xlabel("Time (ms)")
ax[2].set_ylabel("Output Spikes")
ax[2].set_yticks([0, 1])
ax[2].set_yticklabels(['', '1'])
ax[2].set_ylim([-0.1, 1.1])

plt.tight_layout()
plt.show()
plt.show()

fig.savefig("lif_simulation.png", bbox_inches="tight")

# %% [markdown]
# ## 2.2 Visualize Decay of LeakyParallel

# %%
firing_rate = 0.05  # spikes per timestep
input_spikes = torch.bernoulli(firing_rate*torch.ones(num_steps, input_size))

# %%
import torch
import matplotlib.pyplot as plt
import snntorch as snn
from snntorch import surrogate

# --- Simulation parameters ---
num_steps = 200
input_size = 1
threshold = 1.0
decays = [0.9, 0.6, 0.3]

# --- Generate input spikes ---
# Manual Spikes
input_spikes = torch.zeros(num_steps, input_size)
input_spikes[10] = 1.0
input_spikes[80:100:5] = 1.0
input_spikes[120:128:2] = 1.0
input_spikes[140:148:4] = 1.0
input_spikes[160:168:4] = 1.0
input_spikes[180:188:4] = 1.0
input_spikes[195] = 1.0

# Automatic spikes
firing_rate = 0.05  # spikes per timestep
input_spikes = torch.bernoulli(firing_rate*torch.ones(num_steps, input_size))


spike_grad = surrogate.atan()

# --- Run simulations ---
all_mem = {}
all_spikes = {}

for beta in decays:
    lif = snn.Leaky(
        beta=beta,
        threshold=threshold,
        spike_grad=spike_grad,
        reset_mechanism="none"
    )
    
    mem = lif.init_leaky()
    mem_rec = []
    spk_rec = []

    for step in range(num_steps):
        x = input_spikes[step].unsqueeze(0)
        spk, mem_out = lif(x, mem)
        mem = mem_out
        mem_rec.append(mem.clone())
        spk_rec.append(spk.clone())
        
    all_mem[beta] = torch.stack(mem_rec).squeeze()
    all_spikes[beta] = torch.stack(spk_rec).squeeze()

# --- Plotting ---
fig, ax = plt.subplots(3, 1, figsize=(12, 8), sharex=True)

# --- Input Spikes as raster ---
input_spike_times = input_spikes.nonzero().squeeze().numpy()
ax[0].vlines(input_spike_times, 0, 1, color='black')
ax[0].set_title("Input Spikes (Raster)")
ax[0].set_ylabel("Input")
ax[0].set_yticks([0.5])
ax[0].set_yticklabels(['1'])
ax[0].set_xlim([0, num_steps])
ax[0].set_ylim([-0.1, 1.1])
ax[0].set_xticks([])

# --- Membrane Potentials ---
for beta, mem_trace in all_mem.items():
    ax[1].plot(mem_trace.numpy(), label=f"β={beta}")
ax[1].axhline(y=threshold, linestyle='--', color='gray', label='Threshold')
ax[1].set_title("Membrane Potential U(t)")
ax[1].set_ylabel("U(t)")
ax[1].set_ylim([-0.1, max(v.max().item() for v in all_mem.values()) + 0.1])
ax[1].text(num_steps - 20, threshold + 0.05, r'$\vartheta$', fontsize=16)
ax[1].legend()

# --- Output Spikes with offsets ---
offset = 1.5
yticks = []
yticklabels = []

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

for i, beta in enumerate(decays):
    spk_trace = all_spikes[beta]
    spike_times = spk_trace.nonzero().squeeze().numpy()
    y_base = i * offset
    ax[2].vlines(
        spike_times, 
        y_base, 
        y_base + 0.8, 
        color=colors[i % len(colors)],  # pick color from default cycle
        label=f"β={beta}"
    )


ax[2].set_title("Output Spikes (Raster with Offsets)")
ax[2].set_xlabel("Time step")
ax[2].set_ylabel("Spikes")
ax[2].set_yticks(yticks)
ax[2].set_yticklabels(yticklabels)
ax[2].set_ylim([-0.5, len(decays)*offset])
ax[2].legend(loc='upper right')

plt.tight_layout()
plt.show()

fig.savefig("leakyParallel_simulation.pdf", bbox_inches="tight")

# %% [markdown]
# ### 2.2 Loss Graphics

# %%
import wandb
import pandas as pd
import seaborn

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: lupos to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
api = wandb.Api()

# Replace with your W&B entity/project
# runs = api.runs("lupos/surrogate-confidence")
# runs = api.runs("lupos/SpikeSynth-Surrogate-Sweep")
# runs = api.runs("lupos/flexible-surrogate")
runs = api.runs("lupos/flexible-printed-network")

# %%
# Collect metrics from each run
data = []
for run in runs:
    summary = run.summary._json_dict
    config = {k: v for k, v in run.config.items() if not k.startswith('_')}
    name = run.name
    history = run.history(samples=1000)  # get all logged points
    history["run_name"] = name
    history["config"] = [config] * len(history)
    data.append(history)

df = pd.concat(data)

# %%
metric_cols = [
    c for c in df.columns
    # if not c.startswith(("gradients", "config", "_")) and "run_name" not in c
]
print(metric_cols)

print(df.head())
# Out:
# ['gradients/network.model.0_pLayer.theta_', '_timestamp', 'gradients/network.model.1_pLayer.theta_', 'gradients/network.model.0_pLayer.SG.SG_Group.2.raw_params_main', 'test_acc_mode_single', 'gradients/network.model.1_pLayer.SG.SG_Group.2.raw_params_main', 'lr', 'gradients/network.model.2_pLayer.SG.SG_Group.1.raw_params_main', 'val_loss', 'fault_history_table_mode_none', 'train_acc', 'trainer/global_step', 'train_loss', 'train_power', 'training_faults_enabled', 'roc_curve_mode_none_table', 'wandb_fault_history_upload_error', 'test_acc_mode_none', 'gradients/network.model.2_pLayer.SG.SG_Group.0.raw_params_main', 'test_power_mode_single', 'epoch', 'val_power', 'test_roc_micro_auc_mode_none', '_step', 'gradients/network.model.1_pLayer.SG.SG_Group.0.raw_params_main', '_runtime', 'gradients/network.model.0_pLayer.SG.SG_Group.0.raw_params_main', 'test_power_mode_none', 'gradients/network.model.2_pLayer.theta_', 'fault_mode_single_flag', 'test_roc_micro_auc', 'roc_curve_mode_single_table', 
# ...

# %%
import numpy as np
import pandas as pd

models = ["SRC_HypOpt", "RSNN_wLMSE", "RSNN_wLMAE"]
models = ["RSNN_wLMSE", "SRNN_Leaky", "RSNN_Leaky_wLayNorm", "SRNN_RLeaky", "RSNN_RLeaky_wLayNorm"]
models = ["SRC_HypOpt", "SRC_64Neurons", "SRC_16Neurons", "SRC_Skip2", "SRC_LayNorm"]
models = ["RNN", "LSTM", "GRU"]
models = ["LeakyParallel"]
models = ["LeakyParallel", "LeakyParallel_w6L", "LeakyParallel_w8L", "LeakyParallel_w10L"]
models = ["LeakyParallel", "LeakyParallel_wBntt", "LeakyParallel_wLayNorm"]
models = ["LeakyParallel", "Leaky", "RLeaky"]
models = ["LeakyParallel", "Leaky", "RLeaky", "Leaky_wLayNorm", "RLeaky_wLayNorm"]
models = ["LeakyParallel", "LeakyParallel_wSkip2", "LeakyParallel_wSkip3"]
models = ["SLSTM", "SLSTM_2L", "SLSTM_8L"]
models = ["LeakyParallel", "GPT_Nano", "SRC"]
models = ["SRC", "SRC_64", "SRC_16", "SRC_LayNorm"]
models = ["RNN", "LSTM", "GRU", "GPT_Femto", "GPT_Nano"]
models = [
    "PSNN_wSurrGPT_woFaults_acuteinflammation", "PSNN_wSurrGPT_woFaults_balancescale", 
    "PSNN_wSurrGPT_woFaults_cbf", "PSNN_wSurrGPT_woFaults_freezersmalltrain", 
    "PSNN_wSurrGPT_woFaults_gunpointmaleversusfemale", "PSNN_wSurrGPT_woFaults_gunpointoldversusyoung", 
    "PSNN_wSurrGPT_woFaults_seeds", 
    "PSNN_wSurrGPT_woFaults_selfregulationscp2", "PSNN_wSurrGPT_woFaults_tictactoe", 
         ]
baseline_model = models[0]

results = []

for model_name in models:
    group = df[df["run_name"].str.startswith(model_name + "_run")].copy()

    # Drop invalid values
    group["val_loss"] = pd.to_numeric(group["val_loss"], errors="coerce")
    group = group[np.isfinite(group["val_loss"])]
    group = group.dropna(subset=["trainer/global_step", "val_loss"])

    if group.empty:
        print(f"⚠️ No valid runs for {model_name}")
        continue

    # Compute stats
    stats = group.groupby("trainer/global_step")["val_loss"].agg(["mean", "std", "count"])

    # Filter out steps that have fewer than 2 valid runs
    stats = stats[stats["count"] >= 2]

    if stats.empty:
        print(f"⚠️ Not enough data for {model_name} (no step with ≥2 runs)")
        continue

    final_step = stats.index.max()
    final_mean = stats.loc[final_step, "mean"]
    final_std  = stats.loc[final_step, "std"]

    results.append({
        "model": model_name,
        "final_mean": final_mean,
        "final_std": final_std,
    })

summary = pd.DataFrame(results)

baseline_mean = summary.loc[summary["model"] == baseline_model, "final_mean"].values[0]
summary["improvement_%"] = (baseline_mean - summary["final_mean"]) / baseline_mean * 100

print("\n=== Clean Model Comparison ===\n")
print(summary.to_string(index=False, float_format="%.4f"))
# Out:
# === Clean Model Comparison ===
#
#                                           model  final_mean  final_std  improvement_%
#        PSNN_wSurrGPT_woFaults_acuteinflammation      0.7255     0.0016         0.0000
#             PSNN_wSurrGPT_woFaults_balancescale      0.8176     0.0255       -12.6909
#                      PSNN_wSurrGPT_woFaults_cbf      1.0727     0.0037       -47.8580
#        PSNN_wSurrGPT_woFaults_freezersmalltrain      0.6939     0.0004         4.3559
# PSNN_wSurrGPT_woFaults_gunpointmaleversusfemale      0.6619     0.0171         8.7666
#   PSNN_wSurrGPT_woFaults_gunpointoldversusyoung      0.6406     0.0276        11.6992
#                    PSNN_wSurrGPT_woFaults_seeds      1.1127     0.0073       -53.3622
#       PSNN_wSurrGPT_woFaults_selfregulationscp2      0.6933     0.0002         4.4349
#                PSNN_wSurrGPT_woFaults_tictactoe      0.5663     0.0470        21.9409

# %%
import matplotlib.pyplot as plt

# Paper-friendly styling
plt.rcParams.update({
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 300,
    "savefig.dpi": 300,
    "font.family": "serif"
})


include = ["GPT_Femto", "GPT_Nano", "RSNN_wHypOptim_4L"]
include = ["RSNN_wHypOptim_4L", "RSNN_wHypOptim_6L", "RSNN_wHypOptim_8L", "RSNN_wHypOptim_10L"]
include = ["RSNN_wHypOptim_4L", "RSNN_wHypOptim_Skip2", "RSNN_wHypOptim_Skip3", "RSNN_wHypOptim_Skip4"]
include = ["RSNN_wHypOpt", "RSNN_wHypOpt_Bntt", "RSNN_wHypOpt_LayNorm"]
include = ["RSNN_wLMSE", "RSNN_wLMAE", "RSNN_wLHuber"]
include = ["SLSTM_4L", "SLSTM_8L"]
include = ["SRC_HypOpt"]
include = ["SRC_HypOpt", "SRC_64Neurons", "SRC_16Neurons", "SRC_Skip2", "SRC_LayNorm"]
include = ["RNN", "LSTM", "GRU"]
include = ["LeakyParallel", "LeakyParallel_w6L", "LeakyParallel_w8L", "LeakyParallel_w10L"]
include = ["LeakyParallel", "LeakyParallel_wBntt", "LeakyParallel_wLayNorm"]
include = ["LeakyParallel", "Leaky", "RLeaky", "Leaky_wLayNorm", "RLeaky_wLayNorm"]
include = ["LeakyParallel", "LeakyParallel_wSkip2", "LeakyParallel_wSkip3"]
include = ["SLSTM", "SLSTM_2L", "SLSTM_8L"]
include = ["SRC", "SRC_64", "SRC_16", "SRC_LayNorm"]
include = ["RNN", "GRU", "LSTM"]
include = ["RNN", "LSTM", "GRU", "GPT_Femto", "GPT_Nano"]
include = [
    "PSNN_wSurrGPT_woFaults_acuteinflammation", "PSNN_wSurrGPT_woFaults_balancescale", 
    "PSNN_wSurrGPT_woFaults_cbf", "PSNN_wSurrGPT_woFaults_freezersmalltrain", 
    "PSNN_wSurrGPT_woFaults_gunpointmaleversusfemale", "PSNN_wSurrGPT_woFaults_gunpointoldversusyoung", 
    "PSNN_wSurrGPT_woFaults_seeds", 
    "PSNN_wSurrGPT_woFaults_selfregulationscp2", "PSNN_wSurrGPT_woFaults_tictactoe", 
         ]

label_map = {
    "PSNN_wSurrGPT_woFaults_acuteinflammation": "Acute",
    "PSNN_wSurrGPT_woFaults_balancescale": "Balance",
    "PSNN_wSurrGPT_woFaults_cbf": "CBF",
    "PSNN_wSurrGPT_woFaults_freezersmalltrain": "Freezer",
    "PSNN_wSurrGPT_woFaults_gunpointmaleversusfemale": "Gun-MF",
    "PSNN_wSurrGPT_woFaults_gunpointoldversusyoung": "Gun-OY",
    "PSNN_wSurrGPT_woFaults_seeds": "Seeds",
    "PSNN_wSurrGPT_woFaults_selfregulationscp2": "SelfReg",
    "PSNN_wSurrGPT_woFaults_tictactoe": "TicTacToe",
}

window = 1  # smoothing window, bigger smoother

fig, ax = plt.subplots(figsize=(6, 4))

for model_name in include:
    # select all runs with this model name, checks if multiple exist when trained with seed
    group = df[df["run_name"].str.startswith(model_name + "_run")].dropna(subset=["epoch", "val_loss"])

    # Print summary of matched runs
    matched_runs = group["run_name"].unique()
    print(f"\nModel pattern: {model_name}")
    print(f"Matched runs ({len(matched_runs)}): {matched_runs}")
    print(f"Total rows in group: {len(group)}")
    
    if len(group) == 0:
        continue
    
    # Compute mean and std at each step
    stats = group.groupby("epoch")["val_loss"].agg(["mean", "std"])
    
    # Optional smoothing
    stats["mean"] = stats["mean"].rolling(window, min_periods=1).mean()
    
    # Plot mean line
    ax.plot(stats.index, stats["mean"], label=label_map.get(model_name, name_map.get(model_name, model_name)), alpha=0.8)
    
    # Shaded ±1 std
    ax.fill_between(stats.index,
                    stats["mean"] - stats["std"],
                    stats["mean"] + stats["std"],
                    alpha=0.2)
    
    final_step = stats.index.max()
    final_mean = stats.loc[final_step, "mean"]
    final_std = stats.loc[final_step, "std"]
    print(f"Final for {model_name}: step={final_step}, mean={final_mean:.4f}, std={final_std:.4f}")


# Labels, title, grid, legend
# ax.set_yscale("log") 
# ax.set_ylim(top=0.25)
ax.set_xlabel("Epochs")
ax.set_ylabel("Validation Loss")
# ax.set_title("Validation Loss Across Runs")
ax.grid(True, linestyle="--", alpha=0.3)
ax.legend(loc="upper right", frameon=True, fontsize=6)

plt.tight_layout()

# Save the figure
# fig.savefig("fully_trained_val_loss.png", bbox_inches="tight")
#fig.savefig("comparsion_normalization.png", bbox_inches="tight")
fig.savefig("flexible_network_training.pdf", bbox_inches="tight")

plt.show()
# Out:
# Model pattern: PSNN_wSurrGPT_woFaults_acuteinflammation
# Matched runs (6): ['PSNN_wSurrGPT_woFaults_acuteinflammation_run1'
#  'PSNN_wSurrGPT_woFaults_acuteinflammation_run2'
#  'PSNN_wSurrGPT_woFaults_acuteinflammation_run3'
#  'PSNN_wSurrGPT_woFaults_acuteinflammation_run4'
#  'PSNN_wSurrGPT_woFaults_acuteinflammation_run5'
#  'PSNN_wSurrGPT_woFaults_acuteinflammation_run6']
# Total rows in group: 1200
# Final for PSNN_wSurrGPT_woFaults_acuteinflammation: step=199.0, mean=0.7255, std=0.0016
#
# Model pattern: PSNN_wSurrGPT_woFaults_balancescale
# Matched runs (4): ['PSNN_wSurrGPT_woFaults_balancescale_run1'
#  'PSNN_wSurrGPT_woFaults_balancescale_run2'
#  'PSNN_wSurrGPT_woFaults_balancescale_run3'
#  'PSNN_wSurrGPT_woFaults_balancescale_run4']
# Total rows in group: 800
# Final for PSNN_wSurrGPT_woFaults_balancescale: step=199.0, mean=0.8176, std=0.0255
#
# Model pattern: PSNN_wSurrGPT_woFaults_cbf
# ...

# %% [markdown]
# ### 2.3 Spiking Activity

# %%
import matplotlib.pyplot as plt

spike_cols = sorted([c for c in df.columns if c.startswith("spikes/train_avg_layer")])
models = ["RSNN_wHypOptim_10L"]
models = ["SRC_HypOpt", "SRC_64Neurons", "SRC_16Neurons", "SRC_Skip2", "SRC_LayNorm"]

plt.figure(figsize=(10, 6))

for model_name in models:
    group = df[df["run_name"] == model_name].dropna(subset=["trainer/global_step"] + spike_cols)
    if len(group) == 0:
        continue

    # Stack multiple runs if you have them (same run_name but different seeds)
    for col in spike_cols:
        # Compute mean and std across runs at each step
        stats = group.groupby("trainer/global_step")[col].agg(["mean", "std"])
        stats["mean"] = stats["mean"].rolling(window=3, min_periods=1).mean()
        
        plt.plot(stats.index, stats["mean"], label=f"{model_name} - {col}")
        plt.fill_between(stats.index, stats["mean"] - stats["std"], stats["mean"] + stats["std"], alpha=0.2)

plt.xlabel("Training Step")
plt.ylabel("Average Spike Rate")
plt.title("Spike Activity Across Layers During Training")
plt.legend(frameon=False, bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid(True, linestyle="--", alpha=0.3)
plt.tight_layout()
plt.savefig("spike_activity_layers_mean_std.pdf", bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_8057/505719924.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(frameon=False, bbox_to_anchor=(1.05, 1), loc="upper left")

# %%
import matplotlib.pyplot as plt
import numpy as np
import re
from matplotlib.ticker import PercentFormatter

# Spike columns sorted by numeric layer index
spike_cols = sorted([c for c in df.columns if c.startswith("spikes/train_avg_layer_")],
                    key=lambda x: int(x.split("_")[-1]))

# Models (prefixes) to include
include = ["SRNN_Leaky", "SRNN_RLeaky", "RSNN_wHypOpt"]
# include = ["RSNN_wHypOpt", "RSNN_wHypOpt_Skip2", "RSNN_wHypOpt_Skip3"]
# include = ["RSNN_wHypOpt", "RSNN_wHypOptim_LayNorm", "RSNN_wHypOptim_BNTT"]


# All runs per model (assumes names end with _run1, _run2, etc.)
grouped_data = []
for model_prefix in include:
    pattern = re.compile(f"^{re.escape(model_prefix)}_run")
    group = df[df["run_name"].str.match(pattern)]
    if len(group) == 0:
        continue

    # Take the last row of each run
    last_steps = group.groupby("run_name").tail(1)
    
    # Compute mean and std across runs for each layer
    means = last_steps[spike_cols].mean()
    stds = last_steps[spike_cols].std()
    
    # Keep only layers with actual data
    valid_layers = means.notna()
    means = means[valid_layers]
    stds = stds[valid_layers]
    grouped_data.append((model_prefix, means, stds))

# Recompute layer indices based on layers that have data
layer_names = grouped_data[0][1].index  # assume all models have same layers
layer_indices = np.arange(len(layer_names))

# Plot
n_models = len(grouped_data)
width = 0.2  # width of each bar
fig, ax = plt.subplots(figsize=(10, 6))
colors = plt.get_cmap("tab10").colors
offset = -width*(n_models-1)/2

for i, (model_name, means, stds) in enumerate(grouped_data):
    positions = layer_indices + offset + i*width
    bars = ax.bar(positions, means.values, width=width, color=colors[i % len(colors)], alpha=0.8, label=model_name)
    
    # Add std as a line on top of the bar
    for x, m, s in zip(positions, means.values, stds.values):
        ax.plot([x, x], [m - s, m + s], color='black', lw=1.5)  # vertical line
        ax.plot([x - width/4, x + width/4], [m + s, m + s], color='black', lw=1.5)  # top cap
        ax.plot([x - width/4, x + width/4], [m - s, m - s], color='black', lw=1.5)  # bottom cap

# Set x-axis tick labels as "0 layer", "1 layer", etc.
ax.set_xticks(layer_indices)
ax.set_xticklabels([f"{c.split('_')[-1]} layer" for c in layer_names])

# Format y-axis as percentage
ax.yaxis.set_major_formatter(PercentFormatter(1.0))  # assumes values are 0-1; use 100 if values are 0-100

ax.set_ylabel("Mean spiking activity (%)")
ax.grid(True, linestyle="--", alpha=0.3)
ax.legend(frameon=False)
plt.tight_layout()
plt.savefig("spike_activity_different_neuron_types.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 2.4 Gradients

# %%
print("grad_cols:", grad_cols)
print("available run_names:", df["run_name"].unique())
print(f"{model_name} - {col}: min={smooth_grad.min()}, max={smooth_grad.max()}")
# Out:
# grad_cols: ['grad_mean/layer_bntt', 'grad_mean/layer_norms', 'grad_mean/lif_layers.0', 'grad_mean/lif_layers.1', 'grad_mean/lif_layers.2', 'grad_mean/lif_layers.3', 'grad_mean/lif_layers.4', 'grad_mean/lif_layers.5', 'grad_mean/lif_layers.6', 'grad_mean/lif_layers.7', 'grad_mean/output_layer']
# available run_names: ['SLSTM_8L_wLayNorm' 'RSNN_wHypOpt_LayNorm_run1'
#  'RSNN_wHypOpt_LayNorm_run2' 'RSNN_wHypOpt_LayNorm_run3'
#  'RSNN_wHypOpt_LayNorm_run4' 'SLSTM_4L_wLayNorm' 'RSNN_wHypOpt_run1'
#  'SLSTM_8L_run1' 'SLSTM_4L_run1' 'RSNN_wHypOpt_Bntt_run1'
#  'RSNN_wHypOpt_run2' 'SLSTM_4L_run2' 'RSNN_wHypOpt_run3'
#  'RSNN_wHypOpt_run4' 'SLSTM_8L_run2']
# SLSTM_8L - grad_mean/output_layer: min=0.0010376092395745218, max=0.06305664777755737

# %% [raw]
# for model_name in include:
#     group = df[df["run_name"].str.startswith(model_name)].dropna(subset=["trainer/global_step", "val_loss"])
#     print(f"\nModel: {model_name}")
#     print("Number of rows in group:", len(group))
#     print("trainer/global_step dtype:", group["trainer/global_step"].dtype)
#
#     for col in grad_cols:
#         if col in group.columns:
#             data_col = group[col].dropna()
#             print(f"{col}: dtype={data_col.dtype}, min={data_col.min()}, max={data_col.max()}, count={len(data_col)}")
#         else:
#             print(f"{col}: NOT FOUND in group")

# %% [raw]
# print(df.columns)
# print(df.filter(like="grad_mean").head(10))

# %%
from scipy.interpolate import Rbf
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------
# Extract val_loss from nested summary dictionary
# ----------------------------------------------------
df1["val_loss"] = df1["summary"].apply(lambda s: s.get("val_loss", np.nan))

# Drop any rows that do not have val_loss
df1_clean = df1.dropna(subset=["val_loss"])
df1_unique1 = df1_clean.groupby(["lr", "dropout"], as_index=False)["val_loss"].mean()
df1_unique2 = df1_clean.groupby(["num_hidden", "num_hidden_layers"], as_index=False)["val_loss"].mean()



# ----------------------------------------------------
# Helper function: create a contour plot
# ----------------------------------------------------
def contour_plot(df, x, y, z, title, name):
    X = df[x].values.astype(float)
    Y = df[y].values.astype(float)
    Z = df[z].values.astype(float)

    # Create grid for plotting
    xi = np.linspace(X.min(), X.max(), 100)
    yi = np.linspace(Y.min(), Y.max(), 100)
    XI, YI = np.meshgrid(xi, yi)

    # Interpolate using RBF
    rbf = Rbf(X, Y, Z, function='multiquadric')  # smooth RBF
    ZI = rbf(XI, YI)

    # Plot contour
    plt.figure(figsize=(7, 5))
    cp = plt.contourf(XI, YI, ZI, levels=30, cmap='coolwarm_r')
    plt.colorbar(cp, label=z)

    # Overlay original points
    plt.scatter(X, Y, c=Z, edgecolor='k', s=50,  cmap='coolwarm_r')
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(title)
    plt.tight_layout()
    plt.savefig(name, bbox_inches="tight")
    plt.show()



# ----------------------------------------------------
# A. 
# ----------------------------------------------------
contour_plot(
    df1_unique1,
    x="lr",
    y="dropout",
    z="val_loss",
    title="Contour: val_loss over (num_hidden_layers, num_hidden)",
    name="hyperparamater_sweep_step1_contour_val_loss_over_layers_num_hidden.pdf"
)

# ----------------------------------------------------
# B. 
# ----------------------------------------------------
contour_plot(
    df1_unique2,
    x="num_hidden",
    y="num_hidden_layers",
    z="val_loss",
    title="Contour: val_loss over (alpha, beta)",
    name="hyperparamater_sweep_step1_contour_val_loss_over_alpha_beta.pdf"
)

# %% [markdown]
# ### 2.3.2 Second Step: Optimizer

# %%
import wandb
import pandas as pd
import seaborn
import polars as ps
import matplotlib.pyplot as plt

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: lupos to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
api = wandb.Api()

# Replace with your W&B entity/project
entity = "lupos"
project = "SpikeSynth-Surrogate-Sweep"
sweep_id = "n2edkczy"

# %%
# Get the sweep
sweep = api.sweep(f"{entity}/{project}/{sweep_id}")

# Get all runs belonging to that sweep
runs = sweep.runs

# Collect run data
records = []
for run in sweep.runs:
    d = {
        "run_id": run.id,
        "name": run.name,
        "state": run.state,
        "summary": dict(run.summary),
    }
    # Flatten config into columns
    for k, v in run.config.items():
        if not k.startswith("_"):  # ignore internal W&B keys
            d[k] = v
    
    records.append(d)

# Create DataFrame
df2 = pd.DataFrame(records)

df2["val_loss"] = df2["summary"].apply(lambda s: s.get("val_loss", np.nan))
df2 = df2.dropna(subset=["val_loss"])

print(df2.head())
# Out:
#      run_id               name     state  \
# 0  9z3z9aib  visionary-sweep-1  finished
# 1  7nns4m1c    logical-sweep-2  finished
# 2  kcp78x6f     atomic-sweep-3  finished
# 3  wb0aa66p       kind-sweep-4  finished
# 4  runmjzt3      peach-sweep-5  finished
#
#                                              summary        lr           eps  \
# 0  {'_runtime': 837, '_step': 39, '_timestamp': 1...  0.007103  5.301737e-08
# 1  {'_runtime': 177, '_step': 39, '_timestamp': 1...  0.000976  1.404193e-07
# 2  {'_runtime': 159, '_step': 39, '_timestamp': 1...  0.000028  1.191996e-07
# 3  {'_runtime': 191, '_step': 39, '_timestamp': 1...  0.006398  1.569883e-07
# 4  {'_runtime': 212, '_step': 39, '_timestamp': 1...  0.007325  9.846984e-07
#
#    beta  alpha     beta1     beta2  ...  use_layernorm  bntt_time_steps  \
# 0   0.8      2  0.934309  0.998158  ...          False              100
# 1   0.8      2  0.972155  0.984227  ...          False              100
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Compute mean and std for detach_rec
detach_stats = df1_clean.groupby("detach_rec")["val_loss"].agg(["mean", "std"]).reset_index()

# Compute mean and std for relu_bypass
relu_stats = df1_clean.groupby("relu_bypass")["val_loss"].agg(["mean", "std"]).reset_index()

# Bar width
bar_width = 0.35
x_detach = np.arange(len(detach_stats))
x_relu = np.arange(len(relu_stats)) + len(detach_stats) + 1  # offset to separate groups

fig, ax = plt.subplots(figsize=(10,6))

# Plot detach_rec bars
ax.bar(x_detach, detach_stats['mean'], yerr=detach_stats['std'], width=bar_width, label="detach_rec", capsize=5)

# Plot relu_bypass bars
ax.bar(x_relu, relu_stats['mean'], yerr=relu_stats['std'], width=bar_width, label="relu_bypass", capsize=5, color='orange')

# X-axis labels: combine detach_rec and relu_bypass
ax.set_xticks(np.concatenate([x_detach, x_relu]))
ax.set_xticklabels(list(detach_stats['detach_rec']) + list(relu_stats['relu_bypass']), rotation=45)

ax.set_ylabel("val_loss")
ax.set_title("Comparison of val_loss for detach_rec and relu_bypass")
ax.legend()
plt.tight_layout()
plt.show()

# %%
plt.rcParams.update({
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 300,
    "savefig.dpi": 300,
    "font.family": "serif"
})

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# ----------------------------------------------------
# Extract val_loss from summary
# ----------------------------------------------------
df2["val_loss"] = df2["summary"].apply(lambda s: s.get("val_loss", np.nan))
df2 = df2.dropna(subset=["val_loss"])

# Sort runs by a proxy for time, e.g., 'run_id' or '_timestamp' if available
# Here we'll sort by W&B _step in summary, fallback to index
df2["_step"] = df2["summary"].apply(lambda s: s.get("_step", np.nan))
df2_sorted = df2.sort_values("_step").reset_index(drop=True)

# Compute cumulative minimum to track best val_loss over time
df2_sorted["best_val_loss"] = df2_sorted["val_loss"].cummin()

# ----------------------------------------------------
# Plot improvement over time
# ----------------------------------------------------
plt.figure(figsize=(10, 6))
plt.plot(df2_sorted.index + 1, df2_sorted["best_val_loss"], marker='o', linestyle='-', color='tab:blue')
# plt.scatter(df2_sorted.index + 1, df2_sorted["val_loss"], color='tab:orange', alpha=0.5, label='Current val_loss')
plt.xlabel("Run Number")
plt.ylabel("Validation Loss")
plt.title("Bayesian Sweep: Improvement over Runs")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.3)
plt.tight_layout()
plt.savefig("hyperparameter_sweep_step2_improvement_bayesian.pdf", bbox_inches="tight")
plt.show()
# Out:
# /tmp/ipykernel_60742/3626625446.py:28: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import plotly.express as px

df2_clean = df2[df2['val_loss'] < 0.2] 

# Make sure all hyperparameters and val_loss exist in df_plot
cols = ['lr', 'beta1', 'beta2', 'eps', 'val_loss']

fig = px.parallel_coordinates(
    df2_clean,
    dimensions=cols,
    color='val_loss',
    # Reverse color scale: RdBu instead of RdBu_r
    color_continuous_scale=px.colors.sequential.RdBu,
    labels={col: col for col in cols},
)

# Force scientific notation for val_loss (and eps if needed)
fig.update_layout(
    title="Parallel Coordinates: val_loss over all hyperparameters",
)

fig.update_coloraxes(colorbar_title="Validation Loss")

# Update axis tick formatting
for dim in fig.data[0]['dimensions']:
    if dim['label'] in ['eps', 'lr']:  # pick any small numbers you want scientific
        dim['tickformat'] = ".1e"  # scientific notation with 1 decimal

fig.update_layout(
    title="Parallel Coordinates of Hyperparameters vs Validation Loss",
    width=1200,
    height=600,
    font=dict(size=12)
)


fig.show()

# %%
import matplotlib.pyplot as plt
import matplotlib

# Get the colormap
cmap = plt.get_cmap("coolwarm", 256)

# Convert all 256 colors to HEX
hex_colors = [matplotlib.colors.rgb2hex(cmap(i)) for i in range(cmap.N)]

# Print or use
print(hex_colors)
# Out:
# ['#3b4cc0', '#3c4ec2', '#3d50c3', '#3e51c5', '#3f53c6', '#4055c8', '#4257c9', '#4358cb', '#445acc', '#455cce', '#465ecf', '#485fd1', '#4961d2', '#4a63d3', '#4b64d5', '#4c66d6', '#4e68d8', '#4f69d9', '#506bda', '#516ddb', '#536edd', '#5470de', '#5572df', '#5673e0', '#5875e1', '#5977e3', '#5a78e4', '#5b7ae5', '#5d7ce6', '#5e7de7', '#5f7fe8', '#6180e9', '#6282ea', '#6384eb', '#6485ec', '#6687ed', '#6788ee', '#688aef', '#6a8bef', '#6b8df0', '#6c8ff1', '#6e90f2', '#6f92f3', '#7093f3', '#7295f4', '#7396f5', '#7597f6', '#7699f6', '#779af7', '#799cf8', '#7a9df8', '#7b9ff9', '#7da0f9', '#7ea1fa', '#80a3fa', '#81a4fb', '#82a6fb', '#84a7fc', '#85a8fc', '#86a9fc', '#88abfd', '#89acfd', '#8badfd', '#8caffe', '#8db0fe', '#8fb1fe', '#90b2fe', '#92b4fe', '#93b5fe', '#94b6ff', '#96b7ff', '#97b8ff', '#98b9ff', '#9abbff', '#9bbcff', '#9dbdff', '#9ebeff', '#9fbfff', '#a1c0ff', '#a2c1ff', '#a3c2fe', '#a5c3fe', '#a6c4fe', '#a7c5fe', '#a9c6fd', '#aac7fd', '#abc8fd', '#adc9fd', '#aec9fc', '#afcafc', '#b1cbf
# ...

# %% [markdown]
# ## 2.5 Compare Loss

# %%
import sys
import os

# Add the project root (one level above utils/)
sys.path.append(os.path.abspath("..")) 

from surrogate.utils.RSNN import SpikeSynth
from pytorch_lightning import Trainer
import wandb

# %%
api = wandb.Api()

# Replace with your W&B entity/project
runs = api.runs("lupos/surrogate-confidence")

# %%
import matplotlib.pyplot as plt
import numpy as np
import re
from matplotlib.ticker import PercentFormatter

# Metrics to plot instead of layers
metric_cols = ["val_loss", "test_r2", "test_pearson", "test_mse", "test_mae"]

# Models (prefixes) to include
include = ["RSNN_wLMSE", "RSNN_wLMAE", "RSNN_wLHuber"]
include = ["SRC_HypOpt"]

grouped_data = []
for model_prefix in include:
    pattern = re.compile(f"^{re.escape(model_prefix)}_run")
    group = df[df["run_name"].str.match(pattern)]
    if len(group) == 0:
        continue

    # Last row of each run
    last_steps = group.groupby("run_name").tail(1)

    # Compute mean & std for the selected metrics
    means = last_steps[metric_cols].mean()
    stds = last_steps[metric_cols].std()

    # Keep only metrics present in the DF
    valid = means.notna()
    means = means[valid]
    stds = stds[valid]
    grouped_data.append((model_prefix, means, stds))

# Metric names and index positions
metric_names = grouped_data[0][1].index
metric_indices = np.arange(len(metric_names))

# Plot
n_models = len(grouped_data)
width = 0.2
fig, ax = plt.subplots(figsize=(10, 6))
colors = plt.get_cmap("tab10").colors
offset = -width*(n_models-1)/2

for i, (model_name, means, stds) in enumerate(grouped_data):
    positions = metric_indices + offset + i*width
    bars = ax.bar(positions, means.values, width=width,
                  color=colors[i % len(colors)], alpha=0.8, label=model_name)

    # Add std as vertical line + caps
    for x, m, s in zip(positions, means.values, stds.values):
        ax.plot([x, x], [m - s, m + s], color='black', lw=1.5)
        ax.plot([x - width/4, x + width/4], [m + s, m + s], color='black', lw=1.5)
        ax.plot([x - width/4, x + width/4], [m - s, m - s], color='black', lw=1.5)

# X-axis labels (just metrics)
ax.set_xticks(metric_indices)
ax.set_xticklabels(metric_names)

ax.set_ylabel("Test Metric Value")
ax.grid(True, linestyle="--", alpha=0.3)
ax.legend(frameon=False)

pretty_names = {
    "val_loss": "Validation Loss(↓)",
    "test_r2": "R² (↑)",
    "test_pearson": "Pearson r (↑)",
    "test_mse": "MSE (↓)",
    "test_mae": "MAE (↓)",
}

ax.set_xticks(metric_indices)
ax.set_xticklabels([pretty_names[m] for m in metric_names])

plt.tight_layout()
plt.savefig("spike_activity_test_metrics.pdf", bbox_inches="tight")
plt.show()

# %%
import re
import numpy as np
import pandas as pd

# metrics & models (use your existing lists if you prefer)
metric_cols = ["test_r2", "test_pearson", "test_mse", "test_mae"]
include = ["RSNN_wLMSE", "RSNN_wLMAE", "RSNN_wLHuber"]
include = ["SRC_HypOpt"]
include = ["LeakyParallel", "LeakyParallel_wHuber", "LeakyParallel_wMAE"]

# build summary rows like in your original code
rows = []
for model_prefix in include:
    pattern = re.compile(f"^{re.escape(model_prefix)}_run")
    group = df[df["run_name"].str.match(pattern)]
    if len(group) == 0:
        # skip if no runs found
        continue

    last_steps = group.groupby("run_name").tail(1)
    means = last_steps[metric_cols].mean()
    stds  = last_steps[metric_cols].std()

    # ensure all metrics exist (fill missing with NaN)
    row = {"model": model_prefix}
    for m in metric_cols:
        row[f"{m}_mean"] = means.get(m, np.nan)
        row[f"{m}_std"]  = stds.get(m, np.nan)
    rows.append(row)

# DataFrame of summary statistics
summary = pd.DataFrame(rows).set_index("model")

if summary.empty:
    print("No matching runs found for the requested models.")
else:
    # Rank R2 and Pearson: higher is better -> ascending=False
    # method='min' gives best performers the lowest integer rank (1 = best)
    summary["rank_r2"] = summary["test_r2_mean"].rank(ascending=False, method="min")
    summary["rank_pearson"] = summary["test_pearson_mean"].rank(ascending=False, method="min")

    # score_1 as requested:
    summary["score_1"] = summary["rank_r2"] + summary["rank_pearson"]

    # sort by score_1 (lower = better)
    summary = summary.sort_values("score_1")

    # print nicely: mean ± std for each metric, then ranks and score
    pd.set_option("display.width", 120)
    for model, r in summary.iterrows():
        print(f"Model: {model}    (score_1 = {int(r['score_1'])})")
        for m in metric_cols:
            mean = r[f"{m}_mean"]
            std  = r[f"{m}_std"]
            if pd.isna(mean):
                print(f"  {m:12}:  --")
            else:
                # choose sensible formatting; 4 decimals is usually OK for metrics
                print(f"  {m:12}:  {mean:.4f} ± {std:.4f}")
        # ranks (guard against NaN ranks)
        rr = int(r["rank_r2"]) if not pd.isna(r["rank_r2"]) else "NA"
        rp = int(r["rank_pearson"]) if not pd.isna(r["rank_pearson"]) else "NA"
        print(f"  rank(R2) = {rr}, rank(Pearson) = {rp}")
        print("-" * 60)

    # also print compact final table
    print("\nFinal ranking (best first):")
    print(summary[["rank_r2", "rank_pearson", "score_1"]].astype(int))
# Out:
# Model: LeakyParallel    (score_1 = 2)
#   test_r2     :  0.0874 ± 0.0030
#   test_pearson:  0.2859 ± 0.0056
#   test_mse    :  0.4514 ± 0.0015
#   test_mae    :  0.5229 ± 0.0055
#   rank(R2) = 1, rank(Pearson) = 1
# ------------------------------------------------------------
# Model: LeakyParallel_wHuber    (score_1 = 4)
#   test_r2     :  0.0738 ± 0.0075
#   test_pearson:  0.2812 ± 0.0148
#   test_mse    :  0.4582 ± 0.0037
#   test_mae    :  0.4952 ± 0.0089
#   rank(R2) = 2, rank(Pearson) = 2
# ------------------------------------------------------------
# Model: LeakyParallel_wMAE    (score_1 = 6)
#   test_r2     :  -0.2051 ± 0.0170
#   test_pearson:  0.2507 ± 0.0165
#   test_mse    :  0.5963 ± 0.0084
#   test_mae    :  0.4243 ± 0.0007
#   rank(R2) = 3, rank(Pearson) = 3
# ------------------------------------------------------------
#
# Final ranking (best first):
#                       rank_r2  rank_pearson  score_1
# model
# LeakyParallel               1             1        2
# ...

# %% [markdown]
# ## Visualize SRC

# %%
import math
from typing import Optional, Tuple

import torch
import torch.nn as nn
from torch import Tensor


class _StraightThroughReLU(torch.autograd.Function):
    """ReLU forward, but backward returns gradient * identity (pass-through).

    Forward: out = max(h, 0)
    Backward: grad_h = grad_output * 1  (for all h)
    """

    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return input.clamp(min=0)

    @staticmethod
    def backward(ctx, grad_output):
        # Pass gradients through unchanged (straight-through estimator)
        grad_input = grad_output.clone()
        return grad_input


class SRC(nn.Module):
    """Spiking Recurrent Cell (SRC) layer.

    This module processes a sequence of input pulses and returns the sequence of
    output pulses (sout) together with the final states (i, h, hs).
    """

    def __init__(
        self,
        input_size: int,
        hidden_size: int,
        *,
        alpha: float = 0.9,
        rho: float = 3.0,
        r: float = 2.0,
        rs: float = -7.0,
        z: float = 0.0,
        zhyp_s: float = 0.9,
        zdep_s: float = 0.0,
        bh_init: float = -4.0,
        bh_max: float = -4.0,
        detach_rec: bool = True,
        relu_bypass: bool = True,
    ):
        super().__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size

        # Learnable weights
        self.Ws = nn.Parameter(torch.empty(hidden_size, input_size))
        nn.init.kaiming_uniform_(self.Ws, a=math.sqrt(5))

        # Learnable bias bh (clamped at forward time)
        self.bh = nn.Parameter(torch.full((hidden_size,), bh_init))
        self.bh_max = float(bh_max)

        # Fixed hyper-parameters (not learnable)
        self.register_buffer("alpha", torch.tensor(float(alpha)))
        self.rho = float(rho)
        self.r = float(r)
        self.rs = float(rs)
        self.z = float(z)
        self.zhyp_s = float(zhyp_s)
        self.zdep_s = float(zdep_s)

        # Behavior flags
        self.detach_rec = bool(detach_rec)
        self.relu_bypass = bool(relu_bypass)

        # choose ReLU autograd behavior
        if self.relu_bypass:
            self._relu = _StraightThroughReLU.apply
        else:
            self._relu = torch.relu

    def reset_parameters(self):
        nn.init.kaiming_uniform_(self.Ws, a=math.sqrt(5))
        with torch.no_grad():
            self.bh.fill_(-6.0)

    def forward(self, sin: Tensor, states: Optional[Tuple[Tensor, Tensor, Tensor]] = None):
        """Forward pass over a sequence.

        Args:
            sin: Tensor with shape (seq_len, batch, input_size)
            states: optional tuple (i0, h0, hs0) each (batch, hidden_size). If
                    None they are initialized to zeros.

        Returns:
            sout: (seq_len, batch, hidden_size) spike outputs (float tensor)
            (i, h, hs): final states (each (batch, hidden_size))
        """
        if sin.dim() != 3:
            raise ValueError("sin must have shape (seq_len, batch, input_size)")
        seq_len, batch, input_size = sin.shape
        if input_size != self.input_size:
            raise ValueError(f"Expected input_size={self.input_size}, got {input_size}")

        device = sin.device

        if states is None:
            i = torch.zeros(batch, self.hidden_size, device=device)
            h = torch.zeros(batch, self.hidden_size, device=device)
            hs = torch.zeros(batch, self.hidden_size, device=device)
        else:
            i, h, hs = states

        # clamp bias to be <= bh_max
        bh_clamped = torch.clamp(self.bh, max=self.bh_max)

        # pre-allocate outputs
        sout_seq = []

        for t in range(seq_len):
            sin_t = sin[t]  # (batch, input_size)

            # Integrator: i[t] = alpha * i[t-1] + Ws @ sin[t]
            # Ws is (hidden, input); we want (batch, hidden) result
            delta = torch.matmul(sin_t, self.Ws.t())  # (batch, hidden)
            i = self.alpha * i + delta

            # x[t] = rho * tanh(i / rho)
            x = self.rho * torch.tanh(i / self.rho)

            # detach recurrent states so gradients don't flow through them in time
            if self.detach_rec:
                h_prev = h.detach()
                hs_prev = hs.detach()
            else:
                h_prev = h
                hs_prev = hs

            # compute zs from previous h (voltage-dependent step)
            # zs = zhyp_s + (zdep_s - zhyp_s) * H(h_prev - 0.5)
            # H implemented as (h_prev > 0.5).float()
            H = (h_prev > 0.5).float()
            zs = self.zhyp_s + (self.zdep_s - self.zhyp_s) * H

            # candidate hidden state: h_candidate = tanh(x + r * h_prev + rs * hs_prev + bh)
            preact = x + self.r * h_prev + self.rs * hs_prev + bh_clamped
            h_candidate = torch.tanh(preact)

            # update h and hs
            h = self.z * h_prev + (1.0 - self.z) * h_candidate
            hs = zs * hs_prev + (1.0 - zs) * h_prev

            # output spikes (forward ReLU, backward either bypassed or normal)
            sout_t = self._relu(h)
            sout_seq.append(sout_t)

        sout = torch.stack(sout_seq, dim=0)
        return sout, (i, h, hs)

# %%
import torch
import matplotlib.pyplot as plt

# --- Simulation parameters ---
num_steps = 200
input_size = 1
hidden_size = 1  # for visualization simplicity

# --- Initialize SRC neuron ---
src = SRC(input_size=input_size, hidden_size=hidden_size)

# --- Generate input spikes ---
input_spikes = torch.zeros(num_steps, 1, input_size)  # (seq_len, batch, input_size)
input_spikes[10, 0, 0] = 1.0
input_spikes[80:100:5, 0, 0] = 1.0
input_spikes[120:128:2, 0, 0] = 1.0
input_spikes[140:148:4, 0, 0] = 1.0
input_spikes[160:168:4, 0, 0] = 1.0
input_spikes[180:188:4, 0, 0] = 1.0
input_spikes[195, 0, 0] = 1.0

# Automatic spikes
firing_rate = 0.3  # spikes per timestep
input_spikes = torch.bernoulli(firing_rate*torch.ones(num_steps, input_size))

# --- Initialize states ---
i = torch.zeros(1, hidden_size)
h = torch.zeros(1, hidden_size)
hs = torch.zeros(1, hidden_size)
bh_clamped = torch.clamp(src.bh, max=src.bh_max)


# --- Record states ---
h_rec = []
sout_rec = []

# --- Step through time manually ---
for t in range(num_steps):
    sin_t = input_spikes[t]

    # Integrator
    delta = torch.matmul(sin_t, src.Ws.t())
    i = src.alpha * i + delta
    x = src.rho * torch.tanh(i / src.rho)

    # Detach recurrent states for gradient flow
    h_prev = h.detach()
    hs_prev = hs.detach()

    # Compute voltage-dependent gate
    H = (h_prev > 0.5).float()
    zs = src.zhyp_s + (src.zdep_s - src.zhyp_s) * H

    # Candidate hidden state
    preact = x + src.r * h_prev + src.rs * hs_prev + bh_clamped
    h_candidate = torch.tanh(preact)

    # Update states
    h = src.z * h_prev + (1.0 - src.z) * h_candidate
    hs = zs * hs_prev + (1.0 - zs) * h_prev

    # Output spikes
    sout_t = src._relu(h)

    # Record
    h_rec.append(h.clone())
    sout_rec.append(sout_t.clone())

# Convert recordings to tensors for plotting
h_rec = torch.stack(h_rec).squeeze(1).squeeze(-1)
sout_rec = torch.stack(sout_rec).squeeze(1).squeeze(-1)
input_plot = input_spikes.squeeze(-1).squeeze(-1)

# --- Convert recordings to NumPy arrays for plotting ---
h_rec = h_rec.detach().cpu().numpy()
sout_rec = sout_rec.detach().cpu().numpy()
input_plot = input_plot.detach().cpu().numpy()

# --- Use default color cycle ---
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

fig, ax = plt.subplots(3, figsize=(8, 6), sharex=True)

# Input Spikes
ax[0].plot(input_plot, color=colors[0])
ax[0].set_title("Input Spikes")
ax[0].set_ylabel("Input")
ax[0].set_yticks([0, 1])
ax[0].set_yticklabels(['', '1'])
ax[0].set_xlim([0, num_steps])
ax[0].set_ylim([-0.1, 1.1])

# Hidden State
ax[1].plot(h_rec, color=colors[1])
ax[1].set_title("Hidden State h(t)")
ax[1].set_ylabel("h(t)")
ax[1].set_ylim([-1.1, 1.1])

# Output Spikes
ax[2].plot(sout_rec, color=colors[2])
ax[2].set_title("Output Spikes S_out(t)")
ax[2].set_xlabel("Time (ms)")
ax[2].set_ylabel("S_out")
ax[2].set_yticks([0, 1])
ax[2].set_yticklabels(['', '1'])
ax[2].set_ylim([-0.1, 1.1])

plt.tight_layout()
plt.show()
fig.savefig("src_simulation.pdf", bbox_inches="tight")

# %% [markdown]
# ## Illustration Overfitting

# %%
# Paper-friendly styling
plt.rcParams.update({
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 300,
    "savefig.dpi": 300,
    "font.family": "serif"
})

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(0)
X = np.linspace(0, 10, 30)
y = np.sin(X) + np.random.normal(scale=0.5, size=X.shape)

# Degrees for underfitting, good fit, and overfitting
degrees = [1, 3, 15]
titles = ["Underfitting (degree=1)", "Good fit (degree=3)", "Overfitting (degree=15)"]

# Create side-by-side plots and assign figure to a variable
fig, axes = plt.subplots(1, 3, figsize=(20, 6))  # bigger figure
X_fit = np.linspace(0, 10, 500)  # smoother lines

for i, degree in enumerate(degrees):
    coeffs = np.polyfit(X, y, degree)
    y_fit = np.polyval(coeffs, X_fit)
    
    axes[i].scatter(X, y, color='blue', s=60, label='Data')  # bigger points
    axes[i].plot(X_fit, y_fit, color='red', linewidth=2, label='Model')  # thicker line
    axes[i].set_title(titles[i], fontsize=16)
    axes[i].set_xlabel("X", fontsize=14)
    axes[i].set_ylabel("y", fontsize=14)
    axes[i].set_ylim(-2, 2)
    axes[i].tick_params(labelsize=12)
    axes[i].legend(fontsize=12)

plt.tight_layout()
# Save the figure
fig.savefig("overfitting_underfitting_large.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Datsets Summary

# %%
import os
import logging
from Loader import GetDataLoader
import pandas as pd

try:
    from tqdm import tqdm
except Exception:
    tqdm = lambda x: x

logging.basicConfig(level=logging.INFO)

# ---------------------------------------------------------
# Arguments (matching your original script)
# ---------------------------------------------------------
class Args:
    DataPath = '../dataset'
    task = 'normal'
    DATASET = 0
    augment = False
    NOISE_LEVEL = 0
    WARP_FACTOR = 1.0
    SFR_down = 1.0
    SFR_up = 1.0
    CROP_SIZE = None
    R_train = 100
    R_test = 100
    DEVICE = "cpu"
    InputNoise = 0.01
    DS_VAR = 'none'
    N_time = 10

args = Args()

# ---------------------------------------------------------
# Dataset lists
# ---------------------------------------------------------
normal_datasets = [
    'Dataset_acuteinflammation.ds',
    'Dataset_balancescale.ds',
    'Dataset_breastcancerwisc.ds',
    'Dataset_cardiotocography3clases.ds',
    'Dataset_energyy1.ds'
]

temporal_datasets = [
    'Dataset_cbf.tsds',
    'Dataset_distalphalanxtw.tsds',
    'Dataset_freezerregulartrain.tsds',
    'Dataset_gunpointagespan.tsds',
    'Dataset_middlephalanxoutlineagegroup.tsds',
    'Dataset_mixedshapesregulartrain.tsds',
    'Dataset_powercons.tsds',
    'Dataset_proximalphalanxoutlinecorrect.tsds',
    'Dataset_selfregulationscp2.tsds',
    'Dataset_slope.tsds'
]

# ---------------------------------------------------------
# Example notes for datasets
# ---------------------------------------------------------
dataset_notes = {
    'Dataset_acuteinflammation.ds': 'Presumptive diagnosis of two diseases of the urinary system',
    'Dataset_balancescale.ds': 'Balance of weights and distances on two sides',
    'Dataset_breastcancerwisc.ds': 'Classify Breast Cancer',
    'Dataset_cardiotocography3clases.ds': 'Measurements of fetal heart rate and uterine contraction on cardiotocograms',
    'Dataset_energyy1.ds': 'heating load and cooling load requirements of buildings',
    'Dataset_cbf.tsds': 'CBF signals',
    'Dataset_distalphalanxtw.tsds': 'Hand and finger bone outlines for age and development classification',
    'Dataset_freezerregulartrain.tsds': 'Power consumption data for freezers classification',
    'Dataset_gunpointagespan.tsds': 'Time series of hand movements for classifying Gun vs. Point, actor and age',
    'Dataset_middlephalanxoutlineagegroup.tsds': 'Phalange outlines annotated for age and bone development classification',
    'Dataset_mixedshapesregulartrain.tsds': 'Time series representing shapes: Arrowhead, Butterfly, Fish, Seashell, Shield',
    'Dataset_powercons.tsds': 'Power consumption during warm and cold seasons',
    'Dataset_proximalphalanxoutlinecorrect.tsds': 'Phalange outlines annotated for age and bone development classification',
    'Dataset_selfregulationscp2.tsds': 'EEG data from an ALS patient controlling a cursor via slow cortical potentials',
    'Dataset_slope.tsds': 'Slope temporal dataset'
}

# ---------------------------------------------------------
# Helpers
# ---------------------------------------------------------
def summarize_info(info):
    return {
        'N_feature': info.get('N_feature', '-'),
        'N_class': info.get('N_class', '-'),
        'N_train': info.get('N_train', '-'),
        'N_valid': info.get('N_valid', '-'),
        'N_test': info.get('N_test', '-'),
        'N_time': info.get('N_time', '-'),
    }

# ---------------------------------------------------------
# Extraction function with notes and k-format samples
# ---------------------------------------------------------
def extract_info(dataset_list, type_task, type_ds, base_path):
    rows = []
    args.task = type_task

    for i, ds_name in enumerate(tqdm(dataset_list)):
        args.DATASET = i

        try:
            _, info = GetDataLoader(args, mode='train', path=base_path)
            summary = summarize_info(info)

            n_train = summary.get('N_train', 0)
            n_valid = summary.get('N_valid', 0)
            n_test = summary.get('N_test', 0)

            if isinstance(n_train, int) and isinstance(n_valid, int) and isinstance(n_test, int):
                total_samples = n_train + n_valid + n_test
                total_k = f"{round(total_samples / 1000)}k"
                split_str = f"{round(n_train/total_samples*100)}%/{round(n_valid/total_samples*100)}%/{round(n_test/total_samples*100)}%"
            else:
                total_k = '-'
                split_str = '-'

            rows.append({
                'Dataset': ds_name,
                'Type': type_ds,
                '# Inputs': summary['N_feature'],
                '# Output': summary['N_class'],
                'Samples': total_k,
                #'Split(Train/Valid/Test)': split_str,
                # 'Time': summary['N_time'],
                'Notes': dataset_notes.get(ds_name, '')
            })

        except Exception as e:
            logging.exception(f"Error loading dataset {ds_name}")
            rows.append({
                'Dataset': ds_name,
                'Type': type_ds,
                '# Inputs': 'ERROR',
                '# Output': 'ERROR',
                'Samples': '-',
                #'Split(Train/Valid/Test)': '-',
                # 'Time': '-',
                'Notes': str(e)[:200]
            })

    return rows

# ---------------------------------------------------------
# Collect results
# ---------------------------------------------------------
all_rows = []
all_rows += extract_info(normal_datasets, 'normal', 'normal', args.DataPath)
all_rows += extract_info(temporal_datasets, 'temporal', 'temporal', args.DataPath)

df = pd.DataFrame(all_rows)


# Remove 'Dataset_' prefix and file extensions
df['Dataset'] = df['Dataset'].str.replace('Dataset_', '', regex=False) \
                             .str.replace(r'\.ts?ds$', '', regex=True)

# Escape percent signs so LaTeX won't treat them as comments
#df['Split(Train/Valid/Test)'] = df['Split(Train/Valid/Test)'].astype(str) \
#    .str.replace('%', '\\%', regex=False)



# ---------------------------------------------------------
# Output
# ---------------------------------------------------------
print(df.to_string(index=False))
print("---")
print(df.to_latex(index=False))
# Out:
# ...
# 100%|██████████████████| 10/10 [00:00<00:00, 93.55it/s]
#                       Dataset     Type  # Inputs  # Output Samples                                                                          Notes
#          acuteinflammation.ds   normal         6         2     12k                    Presumptive diagnosis of two diseases of the urinary system
#               balancescale.ds   normal         4         3     58k                                  Balance of weights and distances on two sides
#           breastcancerwisc.ds   normal         9         2     60k                                                         Classify Breast Cancer
#    cardiotocography3clases.ds   normal        21         3     60k    Measurements of fetal heart rate and uterine contraction on cardiotocograms
#                   energyy1.ds   normal         8         3     60k                        heating load and cooling load requirements of buildings
# ...

# %% [markdown]
# ## Compare fault-aware methodology to non fault aware

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import matplotlib.pyplot as plt
from matplotlib import colormaps as mcolormaps

# %%
# Initialize W&B API (make sure you're logged in locally with `wandb login`)
api = wandb.Api()

# Your project
project_path = "lupos/flexible-printed-network"
runs = api.runs(project_path)

# %%
plt.rcParams.update({
    "font.size": 10,
    "axes.labelsize": 10,
    "axes.titlesize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 300,
    "savefig.dpi": 300,
    "font.family": "serif"
})

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps as mcolormaps  # New way

# ----------------------------- CONFIG -----------------------------
experiments = [
    "PSNN_wSurrGPT",
    # Add more if needed
]

fault_levels = [0.0, 10, 20, 30]
metric_names = {level: f"test_acc_fault_{level}" for level in fault_levels}
metric_std_names = {level: f"test_acc_fault_{level}_std" for level in fault_levels}  # Optional

dataset_title_map = {
    "acuteinflammation": "Acute Inflammation",
    "balancescale": "Balance Scale"
}

fault_prob_display = {
    0.0: "Non-Fault Aware(0.0%)",
    0.05: "Fault Aware (0.05%)",
    0.1: "Fault Aware (0.1%)",
}

# Base colormap names (will use different shades + hatches)
base_colormaps = ['Blues', 'Oranges', 'Greens', 'Purples', 'Reds', 'Greys']
hatches = ['', '///', '\\\\', '...', 'xxx', '***']

# -----------------------------------------------------------------
if not experiments:
    raise ValueError("Provide at least one experiment name.")

exp_part = '|'.join(re.escape(exp) for exp in experiments)
regex_pattern = rf'^({exp_part})_FaultProb(?P<fprob>\d+(?:\.\d+)?)_(?P<dataset>[^_]+)$'
regex = re.compile(regex_pattern)

# Detect datasets and training fault probs
datasets = set()
train_fault_probs = set()

for run in runs:
    match = regex.match(run.name)
    if match:
        datasets.add(match.group("dataset"))
        train_fault_probs.add(float(match.group("fprob")))

if not datasets:
    raise ValueError(f"No runs matched the experiments: {experiments}")

datasets = sorted(datasets)
train_fault_probs = sorted(train_fault_probs)

print(f"Detected datasets: {datasets}")
print(f"Detected training fault probabilities: {train_fault_probs}")

# Extract data
data_mean = {ds: {exp: {fp: None for fp in train_fault_probs} for exp in experiments} for ds in datasets}
data_std  = {ds: {exp: {fp: None for fp in train_fault_probs} for exp in experiments} for ds in datasets}

for run in runs:
    match = regex.match(run.name)
    if not match:
        continue
    exp = match.group(1)
    ds = match.group("dataset")
    fp = float(match.group("fprob"))

    means = []
    stds = []
    for level in fault_levels:
        mean_val = run.summary.get(metric_names[level])
        std_val = run.summary.get(metric_std_names.get(level))
        means.append(mean_val * 100 if mean_val is not None else np.nan)
        stds.append(std_val * 100 if std_val is not None else 0)
    data_mean[ds][exp][fp] = means
    data_std[ds][exp][fp] = stds

# Warn about missing
missing = [(ds, exp, fp) for ds in datasets for exp in experiments for fp in train_fault_probs
           if data_mean[ds][exp][fp] is None or all(np.isnan(data_mean[ds][exp][fp]))]
if missing:
    print("Warning: Missing data for:")
    for m in missing:
        print(f"  - {m}")

# ----------------------------- PLOTTING -----------------------------
n_datasets = len(datasets)
n_exps = len(experiments)
n_probs = len(train_fault_probs)

group_width = 0.8
bar_width = group_width / (n_exps * n_probs)

fig, axs = plt.subplots(1, n_datasets, figsize=(5 * n_datasets + 3, 7), sharey=True)
if n_datasets == 1:
    axs = [axs]

legend_handles = []
legend_labels = []

for ax_idx, ds in enumerate(datasets):
    ax = axs[ax_idx]
    x_positions = np.arange(len(fault_levels))

    for exp_idx, exp in enumerate(experiments):
        base_cmap = mcolormaps[base_colormaps[exp_idx % len(base_colormaps)]]  # Fixed deprecation

        for fp_idx, fp in enumerate(train_fault_probs):
            means = data_mean[ds][exp][fp]
            stds = data_std[ds][exp][fp]

            if means is None or all(np.isnan(means)):
                continue

            # Positioning: experiments side-by-side, fault probs clustered
            exp_offset = (exp_idx - (n_exps - 1) / 2) * n_probs * bar_width
            fp_offset = fp_idx * bar_width
            offset = exp_offset + fp_offset
            positions = x_positions + offset

            # Color shade based on fault probability
            norm_idx = fp_idx / max(1, n_probs - 1)
            color = base_cmap(0.3 + 0.5 * norm_idx)
            hatch = hatches[fp_idx % len(hatches)]

            # Only add label for legend on the first dataset
            label = f"{exp} — {fault_prob_display.get(fp, f'{fp:.2f}')}" if ax_idx == 0 else ""

            bars = ax.bar(positions, means, bar_width,
                          yerr=stds if any(s > 0 for s in stds) else None,
                          color=color, hatch=hatch, edgecolor='black', linewidth=0.8,
                          label=label,
                          error_kw={'lw': 1, 'capthick': 1, 'capsize': 4})

            # Collect handle only once
            if ax_idx == 0:
                legend_handles.append(bars[0])
                legend_labels.append(f"{fault_prob_display.get(fp, f'{fp:.2f}')}")

    # Axis formatting
    ax.set_title(dataset_title_map.get(ds, ds), fontsize=14, fontweight='bold', pad=15)
    ax.set_xlabel("Test-Time Fault Level (%)", fontsize=12)
    ax.set_xticks(x_positions)
    ax.set_xticklabels([f"{l}%" for l in fault_levels])
    ax.set_ylim(0, 105)
    ax.grid(True, axis='y', linestyle='--', alpha=0.6, zorder=0)
    ax.set_axisbelow(True)

# Shared y-label
fig.text(0.06, 0.5, "Test Accuracy (%)", va='center', rotation='vertical', fontsize=14)

# Clean legend outside the plot
if legend_handles:
    fig.legend(legend_handles, legend_labels,
               #title="Fault Aware Training vs Non-Fault Aware Training",
               bbox_to_anchor=(0.88, 1.1),
               fontsize=10, title_fontsize=11)

plt.tight_layout()
plt.subplots_adjust(left=0.12, right=0.88, wspace=0.15)
fig.savefig("fault_accuracy_plot.pdf", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 43
#      40 datasets = set()
#      41 train_fault_probs = set()
# ---> 43 for run in runs:
#      44     match = regex.match(run.name)
#      45     if match:
#
# File /nix/store/mz8fy6k49nklzviv72y7mjy2csimkdx0-python3-3.12.11-env/lib/python3.12/site-packages/wandb/apis/paginator.py:105, in Paginator.__next__(self)
#     103 self.index += 1
#     104 if len(self.objects) <= self.index:
# --> 105     if not self._load_page():
#     106         raise StopIteration
#     107     if len(self.objects) <= self.index:
#
# File /nix/store/mz8fy6k49nklzviv72y7mjy2csimkdx0-python3-3.12.11-env/lib/python3.12/site-packages/wandb/apis/paginator.py:86, in Paginator._load_page(self)
#      84     return False
#      85 self.update_variables()
# ---> 86 self._update_response()
# ...

# %% [markdown]
# ## Comapre Fault Aware Methdoology

# %%
import re
import warnings
import pandas as pd
import wandb

# ---- CONFIG ----
PROJECT_PATH = "lupos/flexible-printed-network"
METRIC_NONE = "test_acc_mode_none"
METRIC_SINGLE = "test_acc_mode_single"
METRIC_POWER = "val_power" 

# If empty = autodiscover datasets from names
DATASETS = []  # e.g. ["cbf", "acuteinflammation"]

# ----------------

api = wandb.Api()
runs = list(api.runs(PROJECT_PATH))
print(f"Fetched {len(runs)} runs from {PROJECT_PATH}")

pattern = re.compile(r".*_(?P<method>wFaults|woFaults)_(?P<dataset>[^_]+)_run\d+$")


def parse_run_name(name):
    m = pattern.match(name)
    if not m:
        return None
    return m.group("method"), m.group("dataset")


def get_metric(run, key):
    # try summary first
    val = run.summary.get(key, None)
    if val is not None:
        return float(val)
    # fallback to history
    hist = run.history(keys=[key], pandas=True, samples=50)
    if not hist.empty and key in hist.columns:
        s = hist[key].dropna()
        if not s.empty:
            return float(s.iloc[-1])
    return None


rows = []
skipped = []
for run in runs:
    parsed = parse_run_name(run.name)
    if not parsed:
        skipped.append(run.name)
        continue
    method, dataset = parsed

    if DATASETS and dataset not in DATASETS:
        continue

    v_none = get_metric(run, METRIC_NONE)
    v_single = get_metric(run, METRIC_SINGLE)
    v_power = get_metric(run, METRIC_POWER)  

    if v_none is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": METRIC_NONE,
            "value": v_none,
        })
    if v_single is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": METRIC_SINGLE,
            "value": v_single
        })

    if v_power is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": METRIC_POWER,
            "value": v_power
        })

df = pd.DataFrame(rows)
print(f"Extracted {len(df)} metric rows")

df.head()
# Out:
# Fetched 195 runs from lupos/flexible-printed-network
# Extracted 585 metric rows
#                                              run    method            dataset  \
# 0   PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults  acuteinflammation
# 1   PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults  acuteinflammation
# 2   PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults  acuteinflammation
# 3  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults  acuteinflammation
# 4  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults  acuteinflammation
#
#                  metric     value
# 0    test_acc_mode_none  0.320000
# 1  test_acc_mode_single  0.320000
# 2             val_power  0.193912
# 3    test_acc_mode_none  0.320000
# 4  test_acc_mode_single  0.680000

# %%
df.to_csv("results/flexible_neuromorphic_network_acc.csv")

# %%
def top_k_per_group(df, metric_key, k):
    """
    Return top-k rows per (dataset, method) for the given metric_key.
    Higher `value` is considered better.
    """
    dfm = df[df['metric'] == metric_key].copy()
    if dfm.empty:
        print(f"No rows for metric {metric_key}. Returning empty DataFrame.")
        return dfm

    # sort so highest values come first within each group
    dfm = dfm.sort_values(['dataset', 'method', 'value'], ascending=[True, True, False])
    selected = dfm.groupby(['dataset', 'method'], sort=False).head(k).reset_index(drop=True)

    # reporting / diagnostics
    totals = dfm.groupby(['dataset','method']).size().reset_index(name='total_runs')
    kept = selected.groupby(['dataset','method']).size().reset_index(name='kept_runs')
    report = totals.merge(kept, on=['dataset','method'], how='left').fillna(0)
    report['kept_runs'] = report['kept_runs'].astype(int)
    report = report.sort_values(['dataset','method'])
    print(f"Selection report for metric '{metric_key}':")
    display(report)   # nice Jupyter table
    return selected

# %%
import os

# per-metric dataset filters + Top-K selection
# Set K for each metric
K_NONE = 2
K_SINGLE = 2
K_POWER = 6

# Set which datasets are used for each figure.
# If empty -> use all datasets present in df
idk = [] # idk = ["acuteinflammation", "cbf"]
DATASETS_FILTER_NONE   =  idk  # used only for the no-fault figure
DATASETS_FILTER_SINGLE =  idk              # used only for the single-fault figure
DATASETS_FILTER_POWER  =  idk

# METRIC names must match those in df
METRIC_NONE = "test_acc_mode_none"
METRIC_SINGLE = "test_acc_mode_single"
METRIC_POWER = "val_power" 

# sanity
if 'df' not in globals():
    raise RuntimeError("`df` not found. Run the W&B fetching cell first.")

# Build per-metric raw dfs (apply dataset filtering first)
df_for_none_raw = df[df['dataset'].isin(DATASETS_FILTER_NONE)].copy() if DATASETS_FILTER_NONE else df.copy()
df_for_single_raw = df[df['dataset'].isin(DATASETS_FILTER_SINGLE)].copy() if DATASETS_FILTER_SINGLE else df.copy()
df_for_power_raw = df[df['dataset'].isin(DATASETS_FILTER_POWER)].copy() if DATASETS_FILTER_POWER else df.copy()

# Use your existing top_k_per_group function (defined in the previous cell)
# It returns selected rows for the chosen metric
df_top_none   = top_k_per_group(df_for_none_raw, METRIC_NONE, K_NONE)
df_top_single = top_k_per_group(df_for_single_raw, METRIC_SINGLE, K_SINGLE)
df_top_power  = top_k_per_group(df_for_power_raw, METRIC_POWER, K_POWER) 


os.makedirs("results", exist_ok=True)

# map method names to friendlier labels
method_map = {
    'woFaults': 'no_fault',
    'wFaults': 'single_fault'
}

def aggregate_df_and_save(df_in, out_path):
    # ensure numeric values
    df_in['value'] = pd.to_numeric(df_in['value'], errors='coerce')
    # friendly method label
    df_in['method_label'] = df_in['method'].map(method_map).fillna(df_in['method'])
    # group and aggregate
    df_agg = (
        df_in
        .groupby(['dataset', 'method_label'])['value']
        .agg(mean='mean', std='std')
        .reset_index()
        .rename(columns={'method_label': 'method'})
    )
    df_agg.to_csv(out_path, index=False)
    return df_agg

# Save per-metric aggregated CSVs (keeps your filenames)
df_agg_none = aggregate_df_and_save(df_top_none,  'results/no_fault_acc_summary.csv')
df_agg_single = aggregate_df_and_save(df_top_single, 'results/single_fault_acc_summary.csv')

# Optional combined aggregated view (both metrics together)
df_filtered = pd.concat([df_top_none, df_top_single], ignore_index=True)

print("Saved aggregated CSVs: results/no_fault_acc_summary.csv, results/single_fault_acc_summary.csv, results/aggregated_summary.csv")
# Out:
# Selection report for metric 'test_acc_mode_none':
#                           dataset    method  total_runs  kept_runs
# 0               acuteinflammation   wFaults           6          2
# 1               acuteinflammation  woFaults           6          2
# 2                    balancescale   wFaults           4          2
# 3                    balancescale  woFaults           4          2
# 4                             cbf   wFaults           6          2
# 5                             cbf  woFaults           6          2
# 6                 distalphalanxtw   wFaults           5          2
# 7                 distalphalanxtw  woFaults           6          2
# 8                        energyy1   wFaults           6          2
# 9                        energyy1  woFaults           7          2
# 10                       energyy2   wFaults           5          2
# 11                       energyy2  woFaults           5          2
# ...

# %%
df_top_single
# Out:
#                                                    run    method  \
# 0         PSNN_wSurrGPT_wFaults_acuteinflammation_run5   wFaults
# 1         PSNN_wSurrGPT_wFaults_acuteinflammation_run6   wFaults
# 2         PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 3         PSNN_wSurrGPT_wFaults_acuteinflammation_run2   wFaults
# 4         PSNN_wSurrGPT_wFaults_acuteinflammation_run3   wFaults
# ..                                                 ...       ...
# 178  PSNN_wSurrGPT_woFaults_vertebralcolumn2clases_...  woFaults
# 179  PSNN_wSurrGPT_woFaults_vertebralcolumn2clases_...  woFaults
# 180  PSNN_wSurrGPT_woFaults_vertebralcolumn2clases_...  woFaults
# 181  PSNN_wSurrGPT_woFaults_vertebralcolumn2clases_...  woFaults
# 182  PSNN_wSurrGPT_woFaults_vertebralcolumn2clases_...  woFaults
#
#                     dataset                metric     value  method_label
# 0         acuteinflammation  test_acc_mode_single  0.680000  single_fault
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

FIGSIZE = (12, 6)
DPI = 150

method_names_full = {
    "wFaults": "Fault-Aware Method",
    "woFaults": "Non-Fault-Aware Method"
}


def plot_from_filtered_groupedbars(df_filtered_metric, metric_key,
                                   datasets_order=None, title_suffix="", save_name=None):
    """
    Plot grouped bar chart (mean ± std) for the given metric from the filtered DF,
    print a summary table, and optionally save the figure to `save_name`.
    """
    # select metric rows
    dfm = df_filtered_metric[df_filtered_metric['metric'] == metric_key].copy()
    if dfm.empty:
        print(f"No data for {metric_key} (maybe filtering removed everything).")
        return None

    # dataset order: prefer provided order, else autodiscover from this df
    if datasets_order:
        datasets_order = [d for d in datasets_order if d in dfm['dataset'].unique()]
        if not datasets_order:
            datasets_order = sorted(dfm['dataset'].unique())
    else:
        datasets_order = sorted(dfm['dataset'].unique())

    # compute mean, std, count for the bars
    stats = (
        dfm.groupby(['dataset', 'method'], observed=False)['value']
           .agg(['mean', 'std', 'count'])
           .reset_index()
    )

    # --- PRINT SUMMARY TABLE (rounded) ---
    summary_table = stats.copy()
    summary_table['mean'] = summary_table['mean'].round(3)
    summary_table['std']  = summary_table['std'].round(3)
    print(f"\nSummary for metric '{metric_key}':")
    display(summary_table[['dataset', 'method', 'mean', 'std', 'count']])

    # pivot so we have means and stds per method as columns (for plotting)
    means = stats.pivot(index='dataset', columns='method', values='mean').reindex(datasets_order)
    stds  = stats.pivot(index='dataset', columns='method', values='std').reindex(datasets_order)

    methods = ['wFaults', 'woFaults']
    n_datasets = len(datasets_order)
    x = np.arange(n_datasets)

    # plotting params
    total_width = 0.7
    n_methods = len(methods)
    bar_width = total_width / n_methods
    offsets = np.linspace(-total_width/2 + bar_width/2, total_width/2 - bar_width/2, n_methods)

    sns.set(style="whitegrid")
    fig, ax = plt.subplots(figsize=FIGSIZE, dpi=DPI)

    for i, method in enumerate(methods):
        if method not in means.columns:
            continue
        y = means[method].to_numpy(dtype=float)
        yerr = stds[method].to_numpy(dtype=float)
        yerr = np.nan_to_num(yerr, nan=0.0)
        y_plot = np.nan_to_num(y, nan=0.0)

        pos = x + offsets[i]
        # use short method key as label, then remap legend labels afterwards
        ax.bar(pos, y_plot, width=bar_width, label=method, yerr=yerr, capsize=5)

    ax.set_xticks(x)
    ax.set_xticklabels(datasets_order, rotation=0)
    ax.set_xlabel("Dataset")
    ax.set_ylabel("Accuracy (mean ± std)")
    ax.set_title(f"{metric_key} {title_suffix}".strip())

    # map legend labels to full names
    handles, labels = ax.get_legend_handles_labels()
    labels = [method_names_full.get(l, l) for l in labels]
    ax.legend(handles, labels, title="Method", loc="upper right")

    fig.tight_layout()

    # save using the figure object BEFORE plt.show()
    if save_name:
        fig.savefig(save_name, dpi=DPI, bbox_inches='tight')
        print(f"Figure saved to {save_name}")

    plt.show()
    return summary_table

summary_none = plot_from_filtered_groupedbars(
    df_top_none, METRIC_NONE,
    datasets_order=DATASETS_FILTER_NONE or None,
    title_suffix="(Without any fault injected during testing)",
    save_name="avg_acc_wo_fault_injection.pdf"
)

summary_single = plot_from_filtered_groupedbars(
    df_top_single, METRIC_SINGLE,
    datasets_order=DATASETS_FILTER_SINGLE or None,
    title_suffix="(With a singular fault injected during testing)",
    save_name="avg_acc_w_fault_injection.pdf"
)

summary_power = plot_from_filtered_groupedbars(
    df_top_power, METRIC_POWER,
    datasets_order=DATASETS_FILTER_POWER or None,
    title_suffix="(Power metric)",
    save_name="power_summary.pdf"
)
# Out:
# Summary for metric 'test_acc_mode_none':
#                           dataset    method   mean    std  count
# 0               acuteinflammation   wFaults  0.440  0.186      6
# 1               acuteinflammation  woFaults  0.440  0.186      6
# 2                    balancescale   wFaults  0.813  0.075      4
# 3                    balancescale  woFaults  0.797  0.055      4
# 4                             cbf   wFaults  0.685  0.143      6
# 5                             cbf  woFaults  0.582  0.120      6
# 6                 distalphalanxtw   wFaults  0.460  0.000      5
# 7                 distalphalanxtw  woFaults  0.460  0.000      6
# 8                        energyy1   wFaults  0.765  0.187      5
# 9                        energyy1  woFaults  0.762  0.192      5
# 10                       energyy2   wFaults  0.679  0.144      3
# 11                       energyy2  woFaults  0.612  0.161      3
# 12              freezersmalltrain   wFaults  0.487  0.041      6
# ...

# %% [markdown]
# ## Get Raw data to csv

# %%
import re
import warnings
import pandas as pd
import wandb

# ---- CONFIG ----
PROJECT_PATH = "lupos/flexible-printed-network"
METRIC_NONE = "test_acc_mode_none"
METRIC_SINGLE = "test_acc_mode_single"

# new metrics: we try a small set of possible keys for each
VAL_LOSS_KEYS = ["val_loss", "test_val_loss", "val_loss_final", "val_loss_epoch"]
VAL_POWER_KEYS = ["val_power", "test_val_power", "val_power_final", "val_power_epoch"]
# ROC keys: general one logged when mode == "none" plus per-mode keys
ROC_GENERIC_KEY = "test_roc_micro_auc"
ROC_MODE_TEMPLATE = "test_roc_micro_auc_mode_{}"  # format with "none" or "single"
ROC_MODES = {"none": "none", "single": "single"}  # map to your naming convention

# If empty = autodiscover datasets from names
DATASETS = []  # e.g. ["cbf", "acuteinflammation"]

# ----------------

api = wandb.Api()
runs = list(api.runs(PROJECT_PATH))
print(f"Fetched {len(runs)} runs from {PROJECT_PATH}")

pattern = re.compile(r".*_(?P<method>wFaults|woFaults)_(?P<dataset>[^_]+)_run\d+$")


def parse_run_name(name):
    m = pattern.match(name)
    if not m:
        return None
    return m.group("method"), m.group("dataset")


def get_metric(run, key):
    """
    Try to get a single metric key:
      1) from run.summary
      2) from run.history (pandas, look at last non-null value)
    Return float or None.
    """
    # try summary first
    val = run.summary.get(key, None)
    if val is not None:
        try:
            return float(val)
        except Exception:
            return None
    # fallback to history (sample limited to 200 to avoid huge downloads)
    try:
        hist = run.history(keys=[key], pandas=True, samples=200)
    except Exception:
        hist = pd.DataFrame()
    if not hist.empty and key in hist.columns:
        s = hist[key].dropna()
        if not s.empty:
            try:
                return float(s.iloc[-1])
            except Exception:
                return None
    return None


def get_first_metric_from_list(run, keys):
    """
    Try a list of keys in order; return the first non-None metric found.
    """
    for k in keys:
        v = get_metric(run, k)
        if v is not None:
            return k, v
    return None, None


rows = []
skipped = []
for run in runs:
    parsed = parse_run_name(run.name)
    if not parsed:
        skipped.append(run.name)
        continue
    method, dataset = parsed

    if DATASETS and dataset not in DATASETS:
        continue

    # existing metrics
    v_none = get_metric(run, METRIC_NONE)
    v_single = get_metric(run, METRIC_SINGLE)

    # new: val_loss
    val_loss_key, v_val_loss = get_first_metric_from_list(run, VAL_LOSS_KEYS)

    # new: val_power
    val_power_key, v_val_power = get_first_metric_from_list(run, VAL_POWER_KEYS)

    # new: ROC
    # check generic key first (the code you pasted logs "test_roc_micro_auc" when mode=="none"),
    # then check per-mode keys
    roc_entries = []
    v_roc_generic = get_metric(run, ROC_GENERIC_KEY)
    if v_roc_generic is not None:
        roc_entries.append(("generic", ROC_GENERIC_KEY, v_roc_generic))

    for mode_label in ROC_MODES.values():
        k = ROC_MODE_TEMPLATE.format(mode_label)
        v = get_metric(run, k)
        if v is not None:
            roc_entries.append((mode_label, k, v))

    # append rows for available metrics (keeps your existing structure)
    if v_none is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": METRIC_NONE,
            "value": v_none
        })
    if v_single is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": METRIC_SINGLE,
            "value": v_single
        })

    if v_val_loss is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": val_loss_key or "val_loss",
            "value": v_val_loss
        })

    if v_val_power is not None:
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": val_power_key or "val_power",
            "value": v_val_power
        })

    # add any found ROC entries (could be multiple keys)
    for mode_label, key_name, val in roc_entries:
        # encode the mode in the metric name (keeps it clear in the CSV)
        rows.append({
            "run": run.name,
            "method": method,
            "dataset": dataset,
            "metric": key_name,
            "roc_mode": mode_label,
            "value": val
        })

df = pd.DataFrame(rows)
print(f"Extracted {len(df)} metric rows")
if skipped:
    print(f"Skipped {len(skipped)} runs due to name parsing mismatch (examples): {skipped[:10]}")

# Save CSV for your supervisors (raw data)
out_csv = f"raw_metrics_{PROJECT_PATH.replace('/', '_')}.csv"
df.to_csv(out_csv, index=False)
print(f"Wrote raw CSV: {out_csv}")

# quick view
print(df.head(50))
# Out:
# Fetched 195 runs from lupos/flexible-printed-network
# Extracted 1365 metric rows
# Wrote raw CSV: raw_metrics_lupos_flexible-printed-network.csv
#                                               run    method  \
# 0    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 1    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 2    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 3    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 4    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 5    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 6    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 7   PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 8   PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 9   PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 10  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 11  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# ...

# %%
df.head(20)
# Out:
#                                               run    method  \
# 0    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 1    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 2    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 3    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 4    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 5    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 6    PSNN_wSurrGPT_wFaults_acuteinflammation_run1   wFaults
# 7   PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 8   PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 9   PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 10  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 11  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 12  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 13  PSNN_wSurrGPT_woFaults_acuteinflammation_run1  woFaults
# 14                PSNN_wSurrGPT_woFaults_cbf_run1  woFaults
# ...

# %%
df.to_csv("flexible_neuromorphic_network_all_data.csv")

# %% [markdown]
# ## Fault Plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

def make_compact_heatmap(df, group_mode='layer', out_path=None, emphasize_all=True, weighted=False):
    """
    group_mode: 'layer' -> group by fault_layer (compact)
                'layer_cat' -> group by layer + category (medium)
                'location' -> original pretty_location (full detail)

    emphasize_all: if True, adds whitespace + separator line and bolds the Average label
    weighted: if True and group_mode=='layer', compute weighted average using counts
    """
    working = df.copy()
    avg_label = "Layer Average"

    # 1. Prepare Indexing
    if group_mode == 'layer':
        working['fault_layer'] = pd.to_numeric(working['fault_layer'], errors='coerce').astype('Int64')
        pivot_index = working['fault_layer']
        index_name = 'Layer'
    elif group_mode == 'layer_cat':
        working['fault_layer'] = pd.to_numeric(working['fault_layer'], errors='coerce').astype('Int64')
        pivot_index = working['fault_layer'].astype(str).replace('<NA>', 'unknown') + ' / ' + working['fault_category'].astype(str)
        index_name = 'Layer / Category'
    else:
        pivot_index = working['pretty_location']
        index_name = 'Location'

    # 2. Base Pivot Tables
    pivot_mean = working.pivot_table(index=pivot_index, columns='fault_type', values='accuracy', aggfunc='mean')
    pivot_count = working.pivot_table(index=pivot_index, columns='fault_type', values='accuracy', aggfunc='count').fillna(0).astype(int)

    # 3. Handle Sorting and Average Row
    if group_mode == 'layer':
        try:
            pivot_mean = pivot_mean.sort_index()
            pivot_count = pivot_count.reindex(pivot_mean.index)
        except Exception:
            numeric_index = pd.to_numeric(pivot_mean.index, errors='coerce')
            order = numeric_index.argsort(kind='mergesort')
            pivot_mean = pivot_mean.iloc[order]
            pivot_count = pivot_count.reindex(pivot_mean.index)

        # Compute Average
        if weighted:
            weights = pivot_count.astype(float)
            weighted_sum = (pivot_mean.fillna(0) * weights).sum(axis=0)
            total_w = weights.sum(axis=0).replace(0, np.nan)
            all_values = (weighted_sum / total_w).to_frame().T
        else:
            all_values = pivot_mean.mean(axis=0, skipna=True).to_frame().T

        all_values.index = [avg_label]
        all_counts = pivot_count.sum(axis=0).to_frame().T
        all_counts.index = [avg_label]

        # 4. Create Whitespace/Spacer
        if emphasize_all:
            num_dummies = 1 
            dummy_index = [f'_spacer_{i}' for i in range(num_dummies)]
            dummy_mean = pd.DataFrame(np.nan, index=dummy_index, columns=pivot_mean.columns)
            dummy_count = pd.DataFrame(0, index=dummy_index, columns=pivot_count.columns).astype(int)
            
            sep_y = len(pivot_mean) # Line position
            
            new_mean = pd.concat([pivot_mean, dummy_mean, all_values])
            new_count = pd.concat([pivot_count, dummy_count, all_counts])
        else:
            sep_y = None
            new_mean = pd.concat([pivot_mean, all_values])
            new_count = pd.concat([pivot_count, all_counts])
    else:
        sep_y = None
        row_mean = pivot_mean.mean(axis=1, skipna=True)
        new_mean = pivot_mean.loc[row_mean.sort_values().index]
        new_count = pivot_count.reindex(new_mean.index)

    # 5. Build Annotations
    annot = new_mean.copy().astype(object)
    for r in new_mean.index:
        for c in new_mean.columns:
            m = new_mean.at[r, c]
            n = int(new_count.at[r, c])
            if pd.isna(m) or str(r).startswith('_spacer_'):
                annot.at[r, c] = ""
            else:
                annot.at[r, c] = f"{m:.3f}" # f"{m:.3f}\n(n={n})"

    # 6. Plotting
    rows, cols = new_mean.shape
    width = max(8, min(24, 1.1 * cols))
    height = max(3, min(80, 0.45 * rows + 1.5))

    fig, ax = plt.subplots(figsize=(width, height))
    
    # CRITICAL: Disable background grid lines
    ax.grid(False)

    # Create mask for spacer rows to ensure they are empty white space
    mask = np.zeros_like(new_mean, dtype=bool)
    for i, idx in enumerate(new_mean.index):
        if "_spacer_" in str(idx):
            mask[i, :] = True
    
    sns.heatmap(
        new_mean,
        annot=annot.values,
        fmt="",
        linewidths=0.5,
        linecolor="lightgray",
        cbar_kws={'label':'mean accuracy'},
        ax=ax,
        square=False,
        mask=mask,
        facecolor='white'
    )

    # 7. Final Formatting
    if group_mode == 'layer':
        # Custom y-tick labels for layer mode
        ytick_labels = []
        for text in new_mean.index:
            if '_spacer_' in str(text):
                ytick_labels.append("")
            elif isinstance(text, (int, float, pd.Int64Dtype)) and not pd.isna(text):
                ytick_labels.append(f"Layer {int(text)}")
            else:
                ytick_labels.append(str(text))
        
        ax.set_yticks(np.arange(len(ytick_labels)) + 0.5)
        ax.set_yticklabels(ytick_labels, rotation=0, va='center', ha='right')
        ax.tick_params(axis='y', pad=10)
        
        if emphasize_all:
            # Bold the Average label
            for label in ax.get_yticklabels():
                if label.get_text() == avg_label:
                    label.set_fontweight('bold')
    else:
        # For other modes, ensure labels are visible and centered
        ax.set_yticks(np.arange(len(new_mean)) + 0.5)
        ax.set_yticklabels(new_mean.index, rotation=0, va='center')

        ax.tick_params(axis='y', pad=0)

    ax.set_xlabel("Fault Type")
    ax.set_ylabel("")

    # 8. Save and Output
    if out_path is None:
        # Note: Ensure 'out_dir' is defined or use a default path
        out_path = f"heatmap_{group_mode}_layer_grouped.pdf"

    plt.savefig(out_path, bbox_inches='tight')
    plt.show()
    print(f"Saved heatmaps: {out_path}")

# Example Usage:
# make_compact_heatmap(your_dataframe, group_mode='layer')

# %%
# fault_analysis_plots.py
import io
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ---------------------------
# Configure input
# ---------------------------
# Put your real file path here (tab-separated). If not found, the code will fall back to the sample.
data_file = "../fault_analysis_results.csv"

# ---------------------------
# Read data
# ---------------------------
if os.path.exists(data_file):
    df = pd.read_csv(data_file, sep=None, engine='python')  # auto-detect separator
else:
    df = pd.read_csv(io.StringIO(sample_data), sep="\t")

# Basic cleaning / ensure types
df['accuracy'] = pd.to_numeric(df['accuracy'], errors='coerce')
# If fault_layer should be numeric:
df['fault_layer'] = pd.to_numeric(df['fault_layer'], errors='coerce')

# Drop rows missing accuracy
df = df.dropna(subset=['accuracy'])

# ---------------------------
# Summary statistics
# ---------------------------
def print_group_summary(group_col, top_n=10):
    grp = df.groupby(group_col)['accuracy'].agg(['mean','count','std']).reset_index()
    grp_sorted = grp.sort_values('mean')  # low mean = worse
    print(f"\n=== Mean accuracy by {group_col} (worst first) ===")
    print(grp_sorted.head(top_n).to_string(index=False))
    print(f"\n=== Mean accuracy by {group_col} (best first) ===")
    print(grp_sorted.tail(top_n).sort_values('mean', ascending=False).to_string(index=False))

print_group_summary('fault_type')
print_group_summary('fault_category')
print_group_summary('fault_location')
print_group_summary('fault_layer')

# Also create a small summary DataFrame for use in plots
summary_fault_type = df.groupby('fault_type')['accuracy'].agg(['mean','count','std']).sort_values('mean')
summary_fault_location = df.groupby('fault_location')['accuracy'].agg(['mean','count','std']).sort_values('mean')

# ---------------------------
# Plotting setup
# ---------------------------
sns.set(style="whitegrid", context="notebook")
plt.rcParams['figure.dpi'] = 120

# Make an output directory for saved figures
out_dir = "fault_plots"
os.makedirs(out_dir, exist_ok=True)

# ---------------------------
# 1) Barplot: mean accuracy by fault_type (with counts)
# ---------------------------
plt.figure(figsize=(8,5))
ax = sns.barplot(data=summary_fault_type.reset_index(), x='fault_type', y='mean', order=summary_fault_type.index)
ax.set_title("Mean accuracy by fault_type (lower = worse)")
ax.set_xlabel("Fault Type")
ax.set_ylabel("Mean Accuracy")
# annotate counts above bars
for p, (_, row) in zip(ax.patches, summary_fault_type.reset_index().iterrows()):
    height = p.get_height()
    ax.annotate(f"n={int(row['count'])}", (p.get_x()+p.get_width()/2., height),
                ha='center', va='bottom', fontsize=9)
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "mean_accuracy_by_fault_type.pdf"))
plt.show()


def prettify_loc(row):
    L = int(row['fault_layer'])
    loc = row['fault_location']
    cat = row['fault_category']

    if cat == "Neuron":
        if loc.startswith("N"):
            n = loc[1:]
            return f"L{L} / Neuron {n}"
        else:
            return f"L{L} / Neuron {loc}"

    if cat == "Connection":
        if "In" in loc and "_Out" in loc:
            i = loc.split("_Out")[0].replace("In","")
            o = loc.split("_Out")[1]
            return f"L{L} / Conn (In{i}→Out{o})"
        else:
            return f"L{L} / Conn {loc}"

    # fallback
    return f"L{L} / {loc}"
    
df['pretty_location'] = df.apply(prettify_loc, axis=1)


# ---------------------------
# 3) Heatmap: mean accuracy by fault_location vs fault_type
# ---------------------------
pivot = df.pivot_table(
    index='pretty_location',
    columns='fault_type',  # or fault_type
    values='accuracy',
    aggfunc='mean'
)

plt.figure(figsize=(10, max(2, 0.4*len(pivot))))
ax = sns.heatmap(pivot, annot=True, fmt=".3f", linewidths=.5, linecolor="lightgray", cbar_kws={'label':'mean accuracy'})
ax.set_title("Mean accuracy: fault location x fault type")
plt.tight_layout()
plt.ylabel("Location of the Fault")
plt.xlabel("Fault Type")
plt.savefig(os.path.join(out_dir, "heatmap_location_vs_type.pdf"))
plt.show()


# ---------------------------
# 4) Countplot: how many samples per fault_type (helps judge reliability)
# ---------------------------
plt.figure(figsize=(7,4))
ax = sns.countplot(data=df, x='fault_type', order=summary_fault_type.index)
ax.set_title("Count per fault_type")
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+p.get_width()/2., p.get_height()),
                ha='center', va='bottom', fontsize=9)
plt.tight_layout()
plt.savefig(os.path.join(out_dir, "counts_by_fault_type.pdf"))
plt.show()

# ---------------------------
# 5) Faceted view: fault_category vs accuracy, colored by fault_type
# ---------------------------
g = sns.catplot(data=df, x='fault_type', y='accuracy', col='fault_category', kind='box',
                col_wrap=2, sharey=True, height=4, aspect=1.2)
g.fig.suptitle("Accuracy by fault_type separated by fault_category", y=1.02)
plt.savefig(os.path.join(out_dir, "by_category_and_type.pdf"))
plt.show()

# ---------------------------
# 6) Heatmap 2: Grouped 
# ---------------------------
make_compact_heatmap(df, group_mode='layer', out_path=os.path.join(out_dir, "heatmap_layer_grouped.pdf"))

# ---------------------------
# Quick programmatic "worst faults" list to help conclusion
# ---------------------------
worst_types = summary_fault_type.head(10)
worst_locations = summary_fault_location.head(10)

print("\n\n--- Quick lists to inspect programmatically ---")
print("\nWorst fault types (low mean accuracy):")
print(worst_types.to_string())

print("\nWorst fault locations (low mean accuracy):")
print(worst_locations.to_string())

print(f"\nSaved all plots into folder: {out_dir}")
# Out:
# === Mean accuracy by fault_type (worst first) ===
# fault_type     mean  count      std
#     static 0.511733    554 0.366237
#    dynamic 0.562919    596 0.372118
#   stuck_on 0.682988   1981 0.345546
#  stuck_off 0.750401   1869 0.320024
#
# === Mean accuracy by fault_type (best first) ===
# fault_type     mean  count      std
#  stuck_off 0.750401   1869 0.320024
#   stuck_on 0.682988   1981 0.345546
#    dynamic 0.562919    596 0.372118
#     static 0.511733    554 0.366237
#
# === Mean accuracy by fault_category (worst first) ===
# fault_category     mean  count      std
#         Neuron 0.538261   1150 0.370022
#     Connection 0.715714   3850 0.335056
#
# === Mean accuracy by fault_category (best first) ===
# fault_category     mean  count      std
#     Connection 0.715714   3850 0.335056
#         Neuron 0.538261   1150 0.370022
#
# === Mean accuracy by fault_location (worst first) ===
# fault_location     mean  count      std
#             N4 0.371257    167 0.333673
# ...

# %% [markdown]
# ## Paper Ready Diagram

# %%
from __future__ import annotations

import os
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from typing import Dict, List, Optional

def synth_samples(mu: float, sd: float, n: int, rng: np.random.Generator) -> np.ndarray:
    """Generate pseudo-replicates from mean/std, clipped to [0,1]."""
    if not np.isfinite(mu):
        return np.full(n, np.nan)
    if (sd <= 0) or (not np.isfinite(sd)):
        return np.full(n, mu)
    s = rng.normal(mu, sd, n)
    return np.clip(s, 0.0, 1.0)

def generate_accuracy_boxplot(
    csv_path: str,
    output_prefix: str,
    method_map: Optional[Dict[str, str]] = None,
    colors: Optional[Dict[str, str]] = None,
    synthetic_n: int = 40,
    rng_seed: int = 7,
    show_text: bool = True,
    xtick_rotation: int = 45,
    figsize: tuple = (12, 5),
    # --- new/changed args ---
    only_non_fault_aware: bool = True,
    methods: Optional[List[str]] = None,
    exclude_datasets: Optional[List[str]] = None,
):
    """
    Reads accuracy data from a CSV and generates a comparison boxplot.

    Changes:
      - default behavior now plots only the non-fault-aware method (set only_non_fault_aware=False to opt out)
      - specify `methods` to override which method labels to plot (takes precedence)
      - specify `exclude_datasets` as a list of dataset names to omit
    """
    # 1. Defaults & Setup
    if method_map is None:
        method_map = {"no_fault": "Non-fault-aware", "single_fault": "Fault-aware"}
    
    if colors is None:
        colors = {"Non-fault-aware": "#8018da", "Fault-aware": "#e81010"}
    
    # decide which methods to plot
    if methods is None:
        if only_non_fault_aware:
            methods = ["Non-fault-aware"]
        else:
            methods = list(colors.keys())

    rng = np.random.default_rng(rng_seed)

    # 2. Read + Process CSV
    df_raw = pd.read_csv(csv_path, sep=None, engine='python')
    df_raw['method'] = df_raw['method'].map(method_map)

    # Pivot the data
    df_pivot = df_raw.pivot(index='dataset', columns='method', values=['mean', 'std'])
    # Safe flattening of multiindex columns (if some methods are missing pivot will still work)
    df_pivot.columns = [f"{meth}_{stat}" for stat, meth in df_pivot.columns]
    acc_stats = df_pivot.reset_index().rename(columns={'dataset': 'Dataset'})

    # Exclude datasets if requested
    if exclude_datasets:
        acc_stats = acc_stats[~acc_stats['Dataset'].isin(exclude_datasets)].reset_index(drop=True)

    datasets = acc_stats["Dataset"].tolist()
    if len(datasets) == 0:
        raise ValueError("No datasets left to plot after applying exclusions.")

    # 3. Build Synthetic Data
    samples = {}
    for _, r in acc_stats.iterrows():
        ds = r["Dataset"]
        samples[ds] = {}
        for m in methods:
            # use Series.get to avoid KeyError if a method column is missing
            mu = r.get(f"{m}_mean", np.nan)
            sd = r.get(f"{m}_std", np.nan)
            samples[ds][m] = synth_samples(mu, sd, synthetic_n, rng)

    # 4. Plot Setup
    mpl.rcParams.update({
        "font.family": "DejaVu Sans",
        "font.size": 18,
        "axes.labelsize": 18,
        "axes.titlesize": 18,
        "xtick.labelsize": 10,
        "ytick.labelsize": 11,
        "axes.linewidth": 1.0,
    })

    fig, ax = plt.subplots(figsize=figsize, dpi=400)
    x = np.arange(len(datasets))
    box_width = 0.30

    # offsets: center when only one method
    if len(methods) > 1:
        offsets = np.linspace(-box_width / 2, box_width / 2, num=len(methods))
    else:
        offsets = np.array([0.0])

    # Y limits with padding
    all_vals = [val for ds_dict in samples.values() for m_vals in ds_dict.values() for val in m_vals]
    clean = np.array(all_vals, dtype=float)
    good_vals = clean[np.isfinite(clean)]
    if good_vals.size > 0:
        ymin, ymax = np.nanmin(good_vals), np.nanmax(good_vals)
        pad = 0.1 * (ymax - ymin if ymax > ymin else 1.0)
        ax.set_ylim(max(0.0, ymin - pad), min(1.0, ymax + pad))
    else:
        ax.set_ylim(0.0, 1.0)

    # 5. Draw Boxes
    for mi, method in enumerate(methods):
        data = [samples[ds][method] for ds in datasets]
        positions = x + offsets[mi]

        bp = ax.boxplot(
            data,
            positions=positions,
            widths=box_width,
            patch_artist=True,
            showfliers=True,
            whis=1.5,
            manage_ticks=False,
        )

        face = colors.get(method, "#777777")
        for box in bp["boxes"]:
            box.set(facecolor=face, edgecolor="black", linewidth=1.0, alpha=0.9)
        for median in bp["medians"]:
            median.set(color="black", linewidth=1.2)
        for flier in bp["fliers"]:
            flier.set(marker="o", markersize=2, markerfacecolor="white", alpha=0.5)

        if show_text:
            for i, pos in enumerate(positions):
                mu = acc_stats.iloc[i].get(f"{method}_mean", np.nan)
                sd = acc_stats.iloc[i].get(f"{method}_std", np.nan)
                med = np.nanmedian(samples[datasets[i]][method])
                if not np.isfinite(med):
                    med = 0.5  # fallback vertical position for text

                if np.isfinite(mu) and np.isfinite(sd):
                    text = f"{mu:.3f}±{sd:.2f}"
                elif np.isfinite(mu):
                    text = f"{mu:.3f}±n/a"
                else:
                    text = "n/a"

                ax.text(
                    pos, med, text,
                    rotation=90, ha="center", va="bottom",
                    fontsize=8.5, color="black", fontweight="bold"
                )

    # 6. Final Touches
    ax.set_ylabel("Accuracy", fontweight="bold")
    ax.set_xticks(x)
    ax.set_xticklabels(datasets, rotation=xtick_rotation, ha="right", fontweight="bold")

    # Legend logic: skip if only non-fault-aware
    if not (only_non_fault_aware and len(methods) == 1 and methods[0] == "Non-fault-aware"):
        handles = [Patch(facecolor=colors.get(m, "#777777"), edgecolor="black", label=m) for m in methods]
        ax.legend(handles=handles, loc="upper left", frameon=False, fontsize=12)

    plt.tight_layout()

    # ensure results directory exists
    os.makedirs("results", exist_ok=True)
    fig.savefig(f"results/{output_prefix}.pdf", bbox_inches="tight")
    fig.savefig(f"results/{output_prefix}.png", bbox_inches="tight")
    plt.show()

# %%
generate_accuracy_boxplot(
    csv_path="results/no_fault_acc_summary_top4.csv",
    output_prefix="no_fault_acc",
    only_non_fault_aware=False,
    show_text = False,
    exclude_datasets=["distalphalanxtw", "energyy1", "energyy2", "iris", "powercons", "proximalphalanxoutlinecorrect", "slope", "vertebralcolumn2clases"]
)

generate_accuracy_boxplot(
    csv_path="results/single_fault_acc_summary_top4.csv",
    output_prefix="single_fault_acc",
    only_non_fault_aware=False,
    show_text = False,
     exclude_datasets=["distalphalanxtw", "energyy1", "energyy2", "iris", "powercons", "proximalphalanxoutlinecorrect", "slope", "vertebralcolumn2clases"]
)

# %%
generate_accuracy_boxplot(
    csv_path="results/no_fault_acc_summary.csv",
    output_prefix="flexible_nn",
    only_non_fault_aware=True,
    show_text = False,
    xtick_rotation=30,
    exclude_datasets=["distalphalanxtw", "energyy1", "energyy2", "iris", "powercons", "proximalphalanxoutlinecorrect", "slope", "vertebralcolumn2clases"]
)

# %% [markdown]
# ## Calculate Training time

# %%
# Notebook-friendly cell: compute training-time mean/std per dataset+method and save CSV
import re
import sys
import math
from collections import defaultdict
from statistics import mean, stdev
import pandas as pd
import wandb
from datetime import datetime, timezone
import csv

# ---------- CONFIG ----------
PROJECT_PATH = "lupos/flexible-printed-network"
UNIT = "minutes"   # choose "seconds", "minutes", or "hours"
OUT_CSV = "results/training_summary.csv"
# ----------------------------

pattern = re.compile(r".*_(?P<method>wFaults|woFaults)_(?P<dataset>[^_]+)_run\d+$", re.IGNORECASE)

def parse_run_name(name):
    if not name:
        return None
    m = pattern.match(name)
    if not m:
        return None
    method = m.group("method")
    dataset = m.group("dataset")
    return method, dataset

def parse_hms_to_seconds(s):
    """Parse numeric or H:M:S or M:S-ish strings into seconds. Returns float or None."""
    if s is None:
        return None
    if isinstance(s, (int, float)):
        return float(s)
    s = str(s).strip()
    # direct numeric
    try:
        return float(s)
    except Exception:
        pass
    # HH:MM:SS or MM:SS
    m = re.match(r'^(\d+):(\d{1,2})(?::(\d{1,2}))?$', s)
    if m:
        g = m.groups()
        if g[2] is None:
            mm = int(g[0]); ss = int(g[1]); return mm*60 + ss
        else:
            hh = int(g[0]); mm = int(g[1]); ss = int(g[2]); return hh*3600 + mm*60 + ss
    # "123 s" or "123 sec"
    m2 = re.search(r'(\d+(\.\d+)?)\s*s(ec)?', s, re.IGNORECASE)
    if m2:
        return float(m2.group(1))
    return None

def parse_iso_datetime(s):
    if s is None:
        return None
    if isinstance(s, datetime):
        dt = s
    else:
        s = str(s)
        try:
            if s.endswith("Z"):
                s2 = s[:-1] + "+00:00"
            else:
                s2 = s
            dt = datetime.fromisoformat(s2)
        except Exception:
            # fallback basic parse attempts
            fmts = ("%Y-%m-%dT%H:%M:%S.%f%z","%Y-%m-%dT%H:%M:%S%z","%Y-%m-%dT%H:%M:%S.%f","%Y-%m-%dT%H:%M:%S")
            dt = None
            for f in fmts:
                try:
                    dt = datetime.strptime(s, f)
                    break
                except Exception:
                    continue
            if dt is None:
                return None
    if dt.tzinfo is None:
        dt = dt.replace(tzinfo=timezone.utc)
    return dt.astimezone(timezone.utc)

def get_runtime_from_run(run):
    """
    Return runtime in seconds or None.
    Tries summary keys, history, and timestamps as fallbacks.
    """
    # 1) summary keys
    summary = {}
    try:
        summary = dict(run.summary._json) if hasattr(run.summary, "_json") else dict(run.summary)
    except Exception:
        try:
            summary = dict(run.summary)
        except Exception:
            summary = {}

    candidate_keys = ["runtime", "training_time", "duration", "_runtime", "runtime_seconds",
                      "total_time", "elapsed_time", "train_time", "time"]
    for k in candidate_keys:
        if k in summary and summary[k] not in (None, ""):
            val = parse_hms_to_seconds(summary[k])
            if val is not None:
                return float(val)

    # 2) try run.history last value for common keys
    for k in candidate_keys + ["_runtime", "runtime_seconds"]:
        try:
            hist = run.history(keys=[k], pandas=True, samples=50)
            if not hist.empty and k in hist.columns:
                s = hist[k].dropna()
                if not s.empty:
                    parsed = parse_hms_to_seconds(s.iloc[-1])
                    if parsed is not None:
                        return float(parsed)
        except Exception:
            pass

    # 3) compute from timestamps if available (created/finished)
    possible_ts = []
    for attr in ("created_at", "finished_at", "started_at", "updated_at"):
        v = getattr(run, attr, None)
        if v:
            possible_ts.append(v)
    try:
        j = run._json if hasattr(run, "_json") else {}
        if isinstance(j, dict):
            for cand in ("createdAt","created_at","startTime","start_time","endTime","end_time","finishedAt"):
                if cand in j and j[cand]:
                    possible_ts.append(j[cand])
    except Exception:
        pass

    dt_list = []
    for v in possible_ts:
        dt = parse_iso_datetime(v)
        if dt is not None:
            dt_list.append(dt)
    if dt_list:
        dt_list = sorted(dt_list)
        start = dt_list[0]
        end = dt_list[-1]
        if end > start:
            return (end - start).total_seconds()

    return None

# fetch runs
api = wandb.Api()
print(f"Fetching runs from {PROJECT_PATH} ...")
runs = list(api.runs(PROJECT_PATH))
print(f"Fetched {len(runs)} runs from {PROJECT_PATH}")

rows = []
skipped_runs = []
for run in runs:
    # run.name may be None for some runs; fall back to id
    run_name = getattr(run, "name", None) or getattr(run, "display_name", None) or getattr(run, "id", None)
    parsed = parse_run_name(run_name)
    if not parsed:
        skipped_runs.append(run_name)
        continue
    method, dataset = parsed
    runtime_s = get_runtime_from_run(run)

    if runtime_s is None:
        skipped_runs.append(run_name)
        continue

    rows.append({"run": run_name, "method": method, "dataset": dataset, "runtime_s": runtime_s})

print(f"Collected runtime for {len(rows)} runs; skipped {len(skipped_runs)} runs (examples: {skipped_runs[:5]})")

# build DataFrame and aggregate
df = pd.DataFrame(rows)
if df.empty:
    print("No runtime data extracted. Exiting.")
else:
    # normalize case
    df["datasetname"] = df["dataset"].str.lower()
    df["method_norm"] = df["method"].str.lower().str.replace("wofaults","wofault").str.replace("wfaults","wfault")
    # convert units
    if UNIT == "minutes":
        conv = 1.0/60.0
    elif UNIT == "hours":
        conv = 1.0/3600.0
    else:
        conv = 1.0
    df["runtime_unit"] = df["runtime_s"] * conv

    agg = df.groupby(["datasetname","method_norm"], as_index=False)["runtime_unit"].agg(["mean","std","count"]).reset_index()
    # replace NaN std for single-run groups with 0
    agg["std"] = agg["std"].fillna(0.0)
    # round to sensible decimals
    agg["mean"] = agg["mean"].round(4)
    agg["std"] = agg["std"].round(4)

    # prepare final CSV format exactly as requested
    out_df = agg.rename(columns={"method_norm":"method","mean":"mean","std":"std"})[["datasetname","method","mean","std"]]
    out_df.to_csv(OUT_CSV, index=False)
    print(f"Wrote {len(out_df)} rows to {OUT_CSV} (unit = {UNIT}).")
    display(out_df.head(50))  # show up to 50 rows in notebook
# Out:
# Fetching runs from lupos/flexible-printed-network ...
# Fetched 195 runs from lupos/flexible-printed-network
# Collected runtime for 195 runs; skipped 0 runs (examples: [])
# Wrote 34 rows to results/training_summary.csv (unit = minutes).
#                       datasetname   method      mean      std
# 0               acuteinflammation   wfault  173.6250   1.8631
# 1               acuteinflammation  wofault  150.9000   1.1065
# 2                    balancescale   wfault  482.5292   4.0240
# 3                    balancescale  wofault  470.1500   7.1486
# 4                             cbf   wfault  223.3222   3.0156
# 5                             cbf  wofault  217.5083   1.7769
# 6                 distalphalanxtw   wfault  279.5700   5.2793
# 7                 distalphalanxtw  wofault  276.4500   8.3827
# 8                        energyy1   wfault  608.1861  11.5880
# 9                        energyy1  wofault  612.1310  13.6000
# ...

# %% [markdown]
# ## Results to Latex Table

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# ---------- File paths (adjust if needed) ----------
TRAINING_CSV = Path("results/training_summary.csv")   # <-- training times in minutes
SINGLE_FAULT_ACC_CSV = Path("results/single_fault_acc_summary.csv")
NO_FAULT_ACC_CSV = Path("results/no_fault_acc_summary.csv")
OUT_TEX = Path("results/filled_table.tex")

# ---------- Mapping: CSV dataset key -> LaTeX label ----------
DATASET_MAP = {
    "acuteinflammation": "Acute.",
    "balancescale": "Bal.",
    "cbf": "CBF",
    "distalphalanxtw": "Dist. PhalanxTW",
    "energyy1": "En.(y1)",
    "energyy2": "En.(y2)",
    "freezersmalltrain": "FreezerSmall",
    "gunpointmaleversusfemale": "Gunpoint MvF.",
    "gunpointoldversusyoung": "Gunpoint OvY.",
    "iris": "Iris.",
    "powercons": "PowerCons.",
    "proximalphalanxoutlinecorrect": "Prox. PhalanxOC",
    "seeds": "Seeds.",
    "selfregulationscp2": "Selfreg.",
    "slope": "Slope.",
    "tictactoe": "Tictac.",
    "vertebralcolumn2clases": "Vertebral (2C).",
}

# ---------- Formatting options ----------
MEAN_DIGITS = 3
STD_DIGITS = 3
AVERAGE_DDof = 0  # use ddof=0 for population std; set to 1 for sample std

# ---------- Helpers ----------
def read_csv_auto(path: Path) -> pd.DataFrame:
    if not path.exists():
        raise FileNotFoundError(f"Missing file: {path}")
    # allow Pandas to detect separator
    return pd.read_csv(path, sep=None, engine="python")

def get_mu_sigma(df: pd.DataFrame, dataset_key: str, method: str):
    df2 = df.copy()
    # normalize col names to lowercase for lookup
    df2.columns = [c.strip().lower() for c in df2.columns]
    # identify dataset column name
    ds_col = None
    for c in ("dataset", "datasetname", "dataset_name"):
        if c in df2.columns:
            ds_col = c
            break
    if ds_col is None:
        raise ValueError("No dataset column in dataframe")
    if "method" not in df2.columns or "mean" not in df2.columns or "std" not in df2.columns:
        raise ValueError("Expected columns: method, mean, std")
    sel = df2[(df2[ds_col].astype(str).str.lower() == dataset_key.lower()) &
              (df2["method"].astype(str).str.lower() == method.lower())]
    if sel.empty:
        return None, None
    return float(sel["mean"].iloc[0]), float(sel["std"].iloc[0])

def fmt(mu, sigma):
    if mu is None or sigma is None or np.isnan(mu) or np.isnan(sigma):
        return "—"
    return f"{mu:.{MEAN_DIGITS}f} $\\pm$ {sigma:.{STD_DIGITS}f}"

# ---------- Read CSVs ----------
training_df = read_csv_auto(TRAINING_CSV)
single_fault_df = read_csv_auto(SINGLE_FAULT_ACC_CSV)
no_fault_df = read_csv_auto(NO_FAULT_ACC_CSV)

# ---------- Build table rows ----------
rows = []
present_dataset_keys = set()
for csv_key, label in DATASET_MAP.items():
    # Non-fault-aware (use no_fault_acc_summary): No Fault / Fault injected
    nfa_no_mu, nfa_no_std = get_mu_sigma(no_fault_df, csv_key, "no_fault")
    nfa_fault_mu, nfa_fault_std = get_mu_sigma(no_fault_df, csv_key, "single_fault")
    # Fault-aware (use single_fault_acc_summary)
    fa_no_mu, fa_no_std = get_mu_sigma(single_fault_df, csv_key, "no_fault")
    fa_fault_mu, fa_fault_std = get_mu_sigma(single_fault_df, csv_key, "single_fault")
    # Training time: use training_summary (wofault -> Non-Fault-Aware, wfault -> Fault-Aware)
    tr_nfa_mu, tr_nfa_std = get_mu_sigma(training_df, csv_key, "wofault")
    tr_fa_mu, tr_fa_std = get_mu_sigma(training_df, csv_key, "wfault")

    # Convert training time from minutes -> hours (if present)
    if tr_nfa_mu is not None:
        tr_nfa_mu = tr_nfa_mu / 60.0
    if tr_nfa_std is not None:
        tr_nfa_std = tr_nfa_std / 60.0
    if tr_fa_mu is not None:
        tr_fa_mu = tr_fa_mu / 60.0
    if tr_fa_std is not None:
        tr_fa_std = tr_fa_std / 60.0

    # Track presence for averages
    if any(v is not None for v in (nfa_no_mu, nfa_fault_mu, fa_no_mu, fa_fault_mu, tr_nfa_mu, tr_fa_mu)):
        present_dataset_keys.add(csv_key.lower())

    rows.append({
        "label": label,
        "nfa_no": (nfa_no_mu, nfa_no_std),
        "nfa_fault": (nfa_fault_mu, nfa_fault_std),
        "fa_no": (fa_no_mu, fa_no_std),
        "fa_fault": (fa_fault_mu, fa_fault_std),
        "tr_nfa": (tr_nfa_mu, tr_nfa_std),
        "tr_fa": (tr_fa_mu, tr_fa_std),
    })

# ---------- Averages (over datasets that had numeric values) ----------
def collect_means(rows, key):
    vals = []
    for r in rows:
        mu, _ = r[key]
        if mu is not None and not np.isnan(mu):
            vals.append(mu)
    return vals

avg_vals = {
    "nfa_no": collect_means(rows, "nfa_no"),
    "nfa_fault": collect_means(rows, "nfa_fault"),
    "fa_no": collect_means(rows, "fa_no"),
    "fa_fault": collect_means(rows, "fa_fault"),
    "tr_nfa": collect_means(rows, "tr_nfa"),
    "tr_fa": collect_means(rows, "tr_fa"),
}

def mean_std_from_list(lst):
    if not lst:
        return None, None
    arr = np.array(lst, dtype=float)
    return float(arr.mean()), float(arr.std(ddof=AVERAGE_DDof))

avg_row = {k: mean_std_from_list(v) for k, v in avg_vals.items()}

# ---------- Compose LaTeX table ----------
latex_header = r"""\begin{table*}[t]
\centering
\caption{Classification accuracy (mean $\pm$ std) under faults injected during testing, along with training time (hours).}
\label{tab:acc_time_faults}
\setlength{\tabcolsep}{5.2pt}
\renewcommand{\arraystretch}{1.18}
\resizebox{\textwidth}{!}{%
\begin{tabular}{lcccccc}
\toprule
\multirow{2}{*}{\textbf{Dataset}} &
\multicolumn{2}{c}{\textbf{Non Fault-Aware}} &
\multicolumn{2}{c}{\textbf{Fault-Aware}} &
\multicolumn{2}{c}{\textbf{Training Time (hours)}} \\
\cmidrule(lr){2-3}\cmidrule(lr){4-5}\cmidrule(lr){6-7}
& \textbf{No Fault} & \textbf{Fault injected}
& \textbf{No Fault} & \textbf{Fault injected}
& \textbf{Non-Fault-Aware} & \textbf{Fault-Aware} \\
\midrule
"""
latex_rows = []
for r in rows:
    def c(pair): return fmt(pair[0], pair[1])
    line = f"{r['label']} & {c(r['nfa_no'])} & {c(r['nfa_fault'])} & {c(r['fa_no'])} & {c(r['fa_fault'])} & {c(r['tr_nfa'])} & {c(r['tr_fa'])} \\\\"
    latex_rows.append(line)

avg_line = ("\\midrule\n"
            "\\textbf{Average} & "
            f"\\textbf{{{fmt(avg_row['nfa_no'][0], avg_row['nfa_no'][1])}}} & "
            f"\\textbf{{{fmt(avg_row['nfa_fault'][0], avg_row['nfa_fault'][1])}}} & "
            f"\\textbf{{{fmt(avg_row['fa_no'][0], avg_row['fa_no'][1])}}} & "
            f"\\textbf{{{fmt(avg_row['fa_fault'][0], avg_row['fa_fault'][1])}}} & "
            f"\\textbf{{{fmt(avg_row['tr_nfa'][0], avg_row['tr_nfa'][1])}}} & "
            f"\\textbf{{{fmt(avg_row['tr_fa'][0], avg_row['tr_fa'][1])}}} \\\\"
            )

latex_footer = r"""\bottomrule
\end{tabular}%
}
\end{table*}
"""

full_table = "\n".join([latex_header] + latex_rows + [avg_line, latex_footer])
OUT_TEX.write_text(full_table)
print(f"Wrote LaTeX table to: {OUT_TEX.resolve()}")

# ---------- Report any dataset keys that were expected but not found ----------
# gather all dataset keys present in the CSVs
present_keys = set()
for df in (training_df, single_fault_df, no_fault_df):
    cols = [c.lower() for c in df.columns]
    if "dataset" in cols:
        present_keys.update(df["dataset"].astype(str).str.lower().unique())
    elif "datasetname" in cols:
        present_keys.update(df["datasetname"].astype(str).str.lower().unique())

missing = [k for k in DATASET_MAP.keys() if k.lower() not in present_keys]
if missing:
    print("Note: the following dataset keys were NOT found in the provided CSVs and were filled with '—':")
    for m in missing:
        print(" -", m)
else:
    print("All mapped datasets were found in the CSVs.")

# Inform about minutes->hours conversion
print("Training times were read from results/training_summary.csv (minutes) and converted to hours in the output table.")
# Out:
# Wrote LaTeX table to: /home/monkeman/SpikeSynth/utils/results/filled_table.tex
# All mapped datasets were found in the CSVs.
# Training times were read from results/training_summary.csv (minutes) and converted to hours in the output table.

# %% [markdown]
# ## Length of Dataset

# %%
from Loader import GetDataLoader

def inspect_all_datasets(args):
    results = []

    # Loop through all dataset indices for the given task
    # (modify for different tasks: normal / split / temporized / temporal)
    task = args.task
    if task in ["temporized", "temporal"]:
        # datasets are sequentially indexed via args.DATASET
        for i in range(50):  # just a high upper bound; will break early if out of range
            args.DATASET = i
            try:
                _, info = GetDataLoader(args, mode='train')
                total = info['N_train'] + info['N_valid'] + info['N_test']
                results.append({
                    'dataset': info['dataname'],
                    'N_train': info['N_train'],
                    'N_valid': info['N_valid'],
                    'N_test': info['N_test'],
                })
                print(f"{info['dataname']}: train={info['N_train']}, valid={info['N_valid']}, test={info['N_test']} ==> total={total}")
            except Exception as e:
                print(f"[STOP] No more datasets at index {i}")
                break

    return results

# %%
from Loader import GetDataLoader

def sum_all_temporized_datasets(args):
    # List of temporized datasets as in Loader
    temporized_datasets = ['Dataset_cbf.tsds',
                           'Dataset_distalphalanxtw.tsds',
                           'Dataset_freezerregulartrain.tsds',
                           'Dataset_freezersmalltrain.tsds',
                           'Dataset_gunpointagespan.tsds',
                           'Dataset_gunpointmaleversusfemale.tsds',
                           'Dataset_gunpointoldversusyoung.tsds',
                           'Dataset_middlephalanxoutlineagegroup.tsds',
                           'Dataset_mixedshapesregulartrain.tsds',
                           'Dataset_powercons.tsds',
                           'Dataset_proximalphalanxoutlinecorrect.tsds',
                           'Dataset_selfregulationscp2.tsds',
                           'Dataset_slope.tsds',
                           'Dataset_smoothsubspace.tsds',
                           'Dataset_symbols.tsds']

    results = []

    for idx in range(len(temporized_datasets)):
        args.DATASET = idx
        train_loader, info = GetDataLoader(args, mode='train')

        total = info['N_train'] + info['N_valid'] + info['N_test']

        results.append({
            'dataset': info['dataname'],
            'train': info['N_train'],
            'valid': info['N_valid'],
            'test': info['N_test'],
            'total': total
        })

        print(f"{info['dataname']}: train={info['N_train']}, valid={info['N_valid']}, test={info['N_test']} ==> total={total}")

    overall_total = sum(r['total'] for r in results)
    print(f"\nTOTAL samples across all temporized datasets: {overall_total}")

    return results

# %%
class Args:
    task = 'temporal'   # or 'normal' / 'temporized' / 'split'
    DataPath = "../dataset"
    DATASET = 0
    DEVICE = 'cpu'
    R_train = 1
    R_test = 1
    augment = False
    NOISE_LEVEL = 0.01
    WARP_FACTOR = 0.1
    SFR_down = 0.8
    SFR_up = 1.2
    CROP_SIZE = 100
    DS_VAR = 'none'

args = Args()
results = inspect_all_datasets(args)
# Out:
# cbf: train=300, valid=100, test=100 ==> total=500
# distalphalanxtw: train=300, valid=100, test=100 ==> total=500
# freezerregulartrain: train=300, valid=100, test=100 ==> total=500
# freezersmalltrain: train=300, valid=100, test=100 ==> total=500
# gunpointagespan: train=270, valid=90, test=91 ==> total=451
# gunpointmaleversusfemale: train=270, valid=90, test=91 ==> total=451
# gunpointoldversusyoung: train=270, valid=90, test=91 ==> total=451
# middlephalanxoutlineagegroup: train=300, valid=100, test=100 ==> total=500
# mixedshapesregulartrain: train=300, valid=100, test=100 ==> total=500
# powercons: train=216, valid=72, test=72 ==> total=360
# proximalphalanxoutlinecorrect: train=300, valid=100, test=100 ==> total=500
# selfregulationscp2: train=228, valid=76, test=76 ==> total=380
# slope: train=300, valid=100, test=100 ==> total=500
# smoothsubspace: train=180, valid=60, test=60 ==> total=300
# symbols: train=300, valid=100, test=100 ==> total=500
# ...

# %%
class Args:
    task = 'temporized'   # or 'normal' / 'temporized' / 'split'
    DataPath = "../dataset"
    DATASET = 0
    DEVICE = 'cpu'
    R_train = 1
    R_test = 1
    augment = False
    NOISE_LEVEL = 0.01
    WARP_FACTOR = 0.1
    SFR_down = 0.8
    SFR_up = 1.2
    CROP_SIZE = 100
    DS_VAR = 'none'
    N_time = 100

args = Args()
results = sum_all_temporized_datasets(args)
# Out:
# acuteinflammation: train=70, valid=23, test=25 ==> total=118
# balancescale: train=373, valid=124, test=79 ==> total=576
# breastcancerwisc: train=397, valid=127, test=79 ==> total=603
# cardiotocography3clases: train=397, valid=127, test=79 ==> total=603
# energyy1: train=397, valid=127, test=79 ==> total=603
# energyy2: train=397, valid=127, test=79 ==> total=603
# iris: train=88, valid=29, test=31 ==> total=148
# mammographic: train=397, valid=127, test=79 ==> total=603
# pendigits: train=397, valid=127, test=79 ==> total=603
# seeds: train=124, valid=41, test=43 ==> total=208
# tictactoe: train=397, valid=127, test=79 ==> total=603
# vertebralcolumn2clases: train=184, valid=61, test=63 ==> total=308
# vertebralcolumn3clases: train=184, valid=61, test=63 ==> total=308
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[68], line 18
#      15     N_time = 100
# ...
